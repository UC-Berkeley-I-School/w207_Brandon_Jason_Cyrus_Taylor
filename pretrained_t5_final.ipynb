# %% [markdown]
# # Benchmark No Fine-tuning

# %%
import pandas as pd
import ast
import numpy as np
from transformers import T5Tokenizer, TFT5ForConditionalGeneration
from sklearn.metrics import precision_score, recall_score, accuracy_score, fbeta_score, classification_report
import tensorflow as tf

# Display the entire sorted DataFrame
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 500)
pd.set_option('display.max_colwidth', None)

# Load data
merged_test_df = pd.read_csv('/Users/cyrusaghaee/DS 207/Final Project/merged_test_df.csv')

# Function to process the merged dataframe
def process_merged_df(merged_df):
    # Convert string representations of lists back to actual lists
    merged_df['FTMNT_MAKE'] = merged_df['FTMNT_MAKE'].apply(ast.literal_eval)

    # Group the data by description and aggregate the compatible makes into lists
    grouped = merged_df.groupby('processed_x_string')['FTMNT_MAKE'].apply(list).reset_index()
    grouped['FTMNT_MAKE'] = grouped['FTMNT_MAKE'].apply(lambda x: list(set(sum(x, []))))

    # Define X and Y
    X = grouped['processed_x_string']
    Y = grouped['FTMNT_MAKE'].apply(lambda x: ', '.join(x))
    
    return X, Y

# Process the test dataset
X_test, Y_test = process_merged_df(merged_test_df)

# Initialize the tokenizer and model with pre-trained T5
tokenizer = T5Tokenizer.from_pretrained('t5-base')
model = TFT5ForConditionalGeneration.from_pretrained('t5-base')

# Tokenize the test inputs and labels
def tokenize_data(data, labels, tokenizer, max_length=512):
    input_encodings = tokenizer(
        list(data),
        max_length=max_length,
        padding='max_length',
        truncation=True,
        return_tensors='tf'
    )
    
    label_encodings = tokenizer(
        list(labels),
        max_length=128,
        padding='max_length',
        truncation=True,
        return_tensors='tf'
    )
    
    return input_encodings, label_encodings

test_encodings, test_labels = tokenize_data(X_test, Y_test, tokenizer)

batch_size = 16

test_dataset = tf.data.Dataset.from_tensor_slices((
    {'input_ids': test_encodings['input_ids'], 'attention_mask': test_encodings['attention_mask'], 'labels': test_labels['input_ids']}
)).batch(batch_size).prefetch(tf.data.experimental.AUTOTUNE)

# Function to evaluate the pre-trained model on the test set
def evaluate_pretrained_model(model, tokenizer, dataset):
    all_preds = []
    all_labels = []

    with tf.device('/CPU:0'):
        for batch in dataset:
            inputs = batch['input_ids']
            attention_mask = batch['attention_mask']
            batch_labels = batch['labels']

            # Generate predictions
            pred_ids = model.generate(input_ids=inputs, attention_mask=attention_mask)
            preds = [set(tokenizer.decode(ids, skip_special_tokens=True).split(', ')) for ids in pred_ids.numpy()]
            labels = [set(tokenizer.decode(ids, skip_special_tokens=True).split(', ')) for ids in batch_labels.numpy()]

            all_preds.extend(preds)
            all_labels.extend(labels)

    # Convert to binary format for multi-label evaluation
    unique_labels = list(set([label for sublist in all_labels for label in sublist]))
    label_to_index = {label: i for i, label in enumerate(unique_labels)}
    
    y_true_bin = np.zeros((len(all_labels), len(unique_labels)))
    y_pred_bin = np.zeros((len(all_preds), len(unique_labels)))
    
    for i, labels in enumerate(all_labels):
        for label in labels:
            if label in label_to_index:
                y_true_bin[i, label_to_index[label]] = 1
    
    for i, preds in enumerate(all_preds):
        for pred in preds:
            if pred in label_to_index:
                y_pred_bin[i, label_to_index[pred]] = 1

    precision = precision_score(y_true_bin, y_pred_bin, average='weighted', zero_division=np.nan)
    recall = recall_score(y_true_bin, y_pred_bin, average='weighted', zero_division=np.nan)
    accuracy = accuracy_score(y_true_bin, y_pred_bin)
    fbeta = fbeta_score(y_true_bin, y_pred_bin, beta=0.2, average='weighted', zero_division=np.nan)
    
    # Generate classification report
    report = classification_report(y_true_bin, y_pred_bin, target_names=unique_labels, zero_division=np.nan)
    
    # Add accuracy to the report
    report_with_accuracy = f"Accuracy: {accuracy:.4f}\n\n{report}"

    return precision, recall, accuracy, fbeta, report_with_accuracy

# Evaluate the pre-trained model on the test set
precision, recall, accuracy, fbeta, report = evaluate_pretrained_model(model, tokenizer, test_dataset)
print(f"Test Precision: {precision}")
print(f"Test Recall: {recall}")
print(f"Test Accuracy: {accuracy}")
print(f"Test F-beta Score: {fbeta}")
print("Classification Report with Accuracy:\n", report)
# Out:
# All PyTorch model weights were used when initializing TFT5ForConditionalGeneration.
#
# All the weights of TFT5ForConditionalGeneration were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFT5ForConditionalGeneration for predictions without further training.
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:837: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length.  recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Test Precision: 1.0
# Test Recall: 0.001177856301531213
# Test Accuracy: 0.002
# Test F-beta Score: 0.022565247039861135
# Classification Report with Accuracy:
#  Accuracy: 0.0020
#
#                          precision    recall  f1-score   support
#
#                 renault        nan      0.00      0.00         1
#                     geo        nan      0.00      0.00         3
#              mitsubishi        nan      0.00      0.00        12
#                  datsun        nan      0.00      0.00         1
#                   acura        nan      0.00      0.00        14
#                  desoto        nan      0.00      0.00         1
#                    saab        nan      0.00      0.00         8
#                     bmw        nan      0.00      0.00        27
#                   lexus        nan      0.00      0.00        12
#                  hummer        nan      0.00      0.00         5
#                   tesla        nan      0.00      0.00         2
#                chrysler        nan      0.00      0.00        24
#                   volvo        nan      0.00      0.00         6
#                     vpg        nan      0.00      0.00         1
#                  subaru        nan      0.00      0.00        10
#                      mg        nan      0.00      0.00         1
#                  daewoo        nan      0.00      0.00         1
#              alfa romeo        nan      0.00      0.00         1
#               de tomaso        nan      0.00      0.00         1
#                 triumph        nan      0.00      0.00         1
#              studebaker        nan      0.00      0.00         1
#                   dodge        nan      0.00      0.00        45
#                   honda        nan      0.00      0.00        26
#                 peugeot        nan      0.00      0.00         1
#            freightliner        nan      0.00      0.00         2
#                    mini        nan      0.00      0.00         3
#                  suzuki        nan      0.00      0.00         6
#                  saturn        nan      0.00      0.00         9
#              volkswagen        nan      0.00      0.00        20
#                 lincoln        nan      0.00      0.00        20
#                   eagle        nan      0.00      0.00         3
#                    fiat        nan      0.00      0.00         2
#                     amc        nan      0.00      0.00         2
#                    jeep        nan      0.00      0.00        24
#                   scion        nan      0.00      0.00         6
# international harvester        nan      0.00      0.00         3
#           mercedes-benz        nan      0.00      0.00        19
#             rolls-royce        nan      0.00      0.00         1
#                 hyundai        nan      0.00      0.00        19
#                 genesis        nan      0.00      0.00         1
#              am general        nan      0.00      0.00         1
#               chevrolet        nan      0.00      0.00        81
#                infiniti        nan      0.00      0.00        11
#              land rover        nan      0.00      0.00         5
#                   buick        nan      0.00      0.00        30
#                   fargo        nan      0.00      0.00         1
#                     ram        nan      0.00      0.00         8
#                    audi        nan      0.00      0.00        15
#                 sunbeam        nan      0.00      0.00         1
#                  jensen        nan      0.00      0.00         1
#                   isuzu        nan      0.00      0.00        11
#               workhorse        nan      0.00      0.00         1
#          sterling truck        nan      0.00      0.00         1
#                kenworth        nan      0.00      0.00         1
#                 checker        nan      0.00      0.00         1
#                  jaguar        nan      0.00      0.00         4
#                daihatsu        nan      0.00      0.00         1
#                    ford       1.00      0.01      0.03        70
#                  toyota        nan      0.00      0.00        36
#                 mercury        nan      0.00      0.00        22
#                     kia        nan      0.00      0.00        17
#                  nissan        nan      0.00      0.00        29
#                 pontiac        nan      0.00      0.00        31
#                cadillac        nan      0.00      0.00        25
#                     gmc        nan      0.00      0.00        49
#              oldsmobile        nan      0.00      0.00        18
#                   mazda        nan      0.00      0.00        17
#                 porsche        nan      0.00      0.00         5
#                plymouth        nan      0.00      0.00        11
#
#               micro avg       1.00      0.00      0.00       849
#               macro avg       1.00      0.00      0.00       849
#            weighted avg       1.00      0.00      0.00       849
#             samples avg       1.00      0.00      0.00       849

# %% [markdown]
# # Build Model w/ Early Stopping

# %%
import pandas as pd
import ast
import numpy as np
from sklearn.model_selection import train_test_split
from transformers import T5Tokenizer, TFT5ForConditionalGeneration, AdamWeightDecay
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from sklearn.metrics import precision_score, accuracy_score, fbeta_score
import tensorflow as tf  # Import TensorFlow


# Display the entire sorted DataFrame
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 500)
pd.set_option('display.max_colwidth', None)

# Load data
merged_train_df = pd.read_csv('/Users/cyrusaghaee/DS 207/Final Project/merged_train_df.csv')
merged_val_df = pd.read_csv('/Users/cyrusaghaee/DS 207/Final Project/merged_val_df.csv')
merged_test_df = pd.read_csv('/Users/cyrusaghaee/DS 207/Final Project/merged_test_df.csv')

# Function to process the merged dataframe
def process_merged_df(merged_df):
    # Convert string representations of lists back to actual lists
    merged_df['FTMNT_MAKE'] = merged_df['FTMNT_MAKE'].apply(ast.literal_eval)

    # Group the data by description and aggregate the compatible makes into lists
    grouped = merged_df.groupby('processed_x_string')['FTMNT_MAKE'].apply(list).reset_index()
    grouped['FTMNT_MAKE'] = grouped['FTMNT_MAKE'].apply(lambda x: list(set(sum(x, []))))

    # Define X and Y
    X = grouped['processed_x_string']
    Y = grouped['FTMNT_MAKE'].apply(lambda x: ', '.join(x))
    
    return X, Y

# Process each dataset
X_train, Y_train = process_merged_df(merged_train_df)
X_val, Y_val = process_merged_df(merged_val_df)
X_test, Y_test = process_merged_df(merged_test_df)

# Initialize the tokenizer and model with T5
tokenizer = T5Tokenizer.from_pretrained('t5-base')
model = TFT5ForConditionalGeneration.from_pretrained('t5-base')

# Tokenize the inputs and labels
def tokenize_data(data, labels, tokenizer, max_length=512):
    input_encodings = tokenizer(
        list(data),
        max_length=max_length,
        padding='max_length',
        truncation=True,
        return_tensors='tf'
    )
    
    label_encodings = tokenizer(
        list(labels),
        max_length=128,
        padding='max_length',
        truncation=True,
        return_tensors='tf'
    )
    
    return input_encodings, label_encodings

train_encodings, train_labels = tokenize_data(X_train, Y_train, tokenizer)
val_encodings, val_labels = tokenize_data(X_val, Y_val, tokenizer)
test_encodings, test_labels = tokenize_data(X_test, Y_test, tokenizer)

batch_size = 16

train_dataset = tf.data.Dataset.from_tensor_slices((
    {'input_ids': train_encodings['input_ids'], 'attention_mask': train_encodings['attention_mask'], 'labels': train_labels['input_ids']}
)).shuffle(1000).batch(batch_size).prefetch(tf.data.experimental.AUTOTUNE)

val_dataset = tf.data.Dataset.from_tensor_slices((
    {'input_ids': val_encodings['input_ids'], 'attention_mask': val_encodings['attention_mask'], 'labels': val_labels['input_ids']}
)).batch(batch_size).prefetch(tf.data.experimental.AUTOTUNE)

test_dataset = tf.data.Dataset.from_tensor_slices((
    {'input_ids': test_encodings['input_ids'], 'attention_mask': test_encodings['attention_mask'], 'labels': test_labels['input_ids']}
)).batch(batch_size).prefetch(tf.data.experimental.AUTOTUNE)

# Compile the model
optimizer = AdamWeightDecay(learning_rate=3e-5)

model.compile(
    optimizer=optimizer,
    loss=SparseCategoricalCrossentropy(from_logits=True)
)
# Out:
# All PyTorch model weights were used when initializing TFT5ForConditionalGeneration.
#
# All the weights of TFT5ForConditionalGeneration were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFT5ForConditionalGeneration for predictions without further training.

# %% [markdown]
# # Train the Model

# %%
# Custom training loop with early stopping
epochs = 100
patience = 3
best_val_loss = float('inf')
patience_counter = 0

for epoch in range(epochs):
    print(f'Epoch {epoch + 1}/{epochs}')
    
    # Training step
    train_loss = 0
    for batch in train_dataset:
        inputs = batch['input_ids']
        attention_mask = batch['attention_mask']
        labels = batch['labels']

        with tf.GradientTape() as tape:
            outputs = model(input_ids=inputs, attention_mask=attention_mask, labels=labels, training=True)
            loss = outputs.loss
            train_loss += loss

        gradients = tape.gradient(loss, model.trainable_variables)
        optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    
    train_loss /= len(train_dataset)
    print(f'Training Loss: {train_loss}')
    
    # Validation step
    val_loss = 0
    for batch in val_dataset:
        inputs = batch['input_ids']
        attention_mask = batch['attention_mask']
        labels = batch['labels']

        outputs = model(input_ids=inputs, attention_mask=attention_mask, labels=labels, training=False)
        loss = outputs.loss
        val_loss += loss
    
    val_loss /= len(val_dataset)
    print(f'Validation Loss: {val_loss}')
    
    # Early stopping check
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
        model.save_weights('./fine_tuned_t5v5.weights.h5')
        model.save_pretrained('./fine_tuned_t5v5')
        tokenizer.save_pretrained('./fine_tuned_t5v5')
    else:
        patience_counter += 1
        if patience_counter >= patience:
            print("Early stopping triggered.")
            break

# Load the best model weights
model.load_weights('./fine_tuned_t5v5.weights.h5')
# Out:
# Epoch 1/100
# Training Loss: [0.6445512]
# Validation Loss: [0.10926604]
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# Epoch 2/100
# Training Loss: [0.09909403]
# Validation Loss: [0.04561129]
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# Epoch 3/100
# Training Loss: [0.05306148]
# Validation Loss: [0.03937169]
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# Epoch 4/100
# Training Loss: [0.0447378]
# Validation Loss: [0.03555105]
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# Epoch 5/100
# Training Loss: [0.0405241]
# Validation Loss: [0.03252235]
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# Epoch 6/100
# Training Loss: [0.03655076]
# Validation Loss: [0.03012721]
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# Epoch 7/100
# Training Loss: [0.03470323]
# Validation Loss: [0.02848039]
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# Epoch 8/100
# Training Loss: [0.03230544]
# Validation Loss: [0.02708086]
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# Epoch 9/100
# Training Loss: [0.03100815]
# Validation Loss: [0.02611739]
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# Epoch 10/100
# Training Loss: [0.0293803]
# Validation Loss: [0.02616521]
# Epoch 11/100
# Training Loss: [0.02803011]
# Validation Loss: [0.02411519]
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# Epoch 12/100
# Training Loss: [0.02692658]
# Validation Loss: [0.02385205]
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# Epoch 13/100
# Training Loss: [0.02606193]
# Validation Loss: [0.02290814]
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# Epoch 14/100
# Training Loss: [0.02502922]
# Validation Loss: [0.02368581]
# Epoch 15/100
# Training Loss: [0.02425716]
# Validation Loss: [0.02264706]
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# Epoch 16/100
# Training Loss: [0.02375524]
# Validation Loss: [0.02174065]
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# Epoch 17/100
# Training Loss: [0.02246848]
# Validation Loss: [0.02135939]
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# Epoch 18/100
# Training Loss: [0.02159163]
# Validation Loss: [0.02068828]
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# Epoch 19/100
# Training Loss: [0.02060034]
# Validation Loss: [0.02082878]
# Epoch 20/100
# Training Loss: [0.0205283]
# Validation Loss: [0.01963025]
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# Epoch 21/100
# Training Loss: [0.01983201]
# Validation Loss: [0.01928295]
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# Epoch 22/100
# Training Loss: [0.01955421]
# Validation Loss: [0.019761]
# Epoch 23/100
# Training Loss: [0.0190254]
# 2024-08-05 21:11:00.530878: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# Validation Loss: [0.01922299]
# Epoch 24/100
# Training Loss: [0.01829443]
# Validation Loss: [0.01837045]
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# Epoch 25/100
# Training Loss: [0.01745993]
# Validation Loss: [0.01776347]
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# Epoch 26/100
# Training Loss: [0.01679077]
# Validation Loss: [0.0171078]
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# Epoch 27/100
# Training Loss: [0.0163037]
# Validation Loss: [0.01735291]
# Epoch 28/100
# Training Loss: [0.01571654]
# Validation Loss: [0.01729555]
# Epoch 29/100
# Training Loss: [0.01495163]
# Validation Loss: [0.01589193]
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# Epoch 30/100
# Training Loss: [0.01477762]
# Validation Loss: [0.01640935]
# Epoch 31/100
# Training Loss: [0.01440358]
# Validation Loss: [0.01596942]
# Epoch 32/100
# Training Loss: [0.01408947]
# Validation Loss: [0.01540047]
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# Epoch 33/100
# Training Loss: [0.01311158]
# Validation Loss: [0.01522288]
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# Epoch 34/100
# Training Loss: [0.01297749]
# Validation Loss: [0.01532779]
# Epoch 35/100
# Training Loss: [0.01263092]
# Validation Loss: [0.014961]
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# Epoch 36/100
# Training Loss: [0.01214198]
# Validation Loss: [0.0143023]
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# Epoch 37/100
# Training Loss: [0.01126035]
# Validation Loss: [0.01347507]
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# Epoch 38/100
# Training Loss: [0.01129726]
# Validation Loss: [0.01401551]
# Epoch 39/100
# Training Loss: [0.01016763]
# Validation Loss: [0.01352121]
# Epoch 40/100
# Training Loss: [0.00986454]
# Validation Loss: [0.01378261]
# Early stopping triggered.
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)

# %% [markdown]
# # Load Saved Model

# %%
# Paths to the saved models and tokenizer
weights3_path = './fine_tuned_t5v3.weights.h5'
model3_path = './fine_tuned_t5v3'

# Load the tokenizer
tokenizer3 = T5Tokenizer.from_pretrained(model3_path)

# Load the model architecture and weights
model3 = TFT5ForConditionalGeneration.from_pretrained(model3_path)
model3.load_weights(weights3_path)



# Paths to the saved models and tokenizer
weights2_path = './fine_tuned_t5v2.weights.h5'
model2_path = './fine_tuned_t5v2'

# Load the tokenizer
tokenizer2 = T5Tokenizer.from_pretrained(model2_path)

# Load the model architecture and weights
model2 = TFT5ForConditionalGeneration.from_pretrained(model2_path)
model2.load_weights(weights2_path)



# Paths to the saved models and tokenizer
weights4_path = './fine_tuned_t5v4.weights.h5'
model4_path = './fine_tuned_t5v4'

# Load the tokenizer
tokenizer4 = T5Tokenizer.from_pretrained(model4_path)

# Load the model architecture and weights
model4 = TFT5ForConditionalGeneration.from_pretrained(model4_path)
model4.load_weights(weights4_path)



# Paths to the saved models and tokenizer
weights5_path = './fine_tuned_t5v5.weights.h5'
model5_path = './fine_tuned_t5v5'

# Load the tokenizer
tokenizer5 = T5Tokenizer.from_pretrained(model5_path)

# Load the model architecture and weights
model5 = TFT5ForConditionalGeneration.from_pretrained(model5_path)
model5.load_weights(weights5_path)
# Out:
# All model checkpoint layers were used when initializing TFT5ForConditionalGeneration.
#
# All the layers of TFT5ForConditionalGeneration were initialized from the model checkpoint at ./fine_tuned_t5v3.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFT5ForConditionalGeneration for predictions without further training.
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# All model checkpoint layers were used when initializing TFT5ForConditionalGeneration.
#
# All the layers of TFT5ForConditionalGeneration were initialized from the model checkpoint at ./fine_tuned_t5v2.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFT5ForConditionalGeneration for predictions without further training.
# All model checkpoint layers were used when initializing TFT5ForConditionalGeneration.
#
# All the layers of TFT5ForConditionalGeneration were initialized from the model checkpoint at ./fine_tuned_t5v4.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFT5ForConditionalGeneration for predictions without further training.
# All model checkpoint layers were used when initializing TFT5ForConditionalGeneration.
#
# All the layers of TFT5ForConditionalGeneration were initialized from the model checkpoint at ./fine_tuned_t5v5.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFT5ForConditionalGeneration for predictions without further training.

# %% [markdown]
# ('./fine_tuned_t5/tokenizer_config.json',
#  './fine_tuned_t5/special_tokens_map.json',
#  './fine_tuned_t5/spiece.model',
#  './fine_tuned_t5/added_tokens.json')

# %% [markdown]
# # Evaluation + Classification Report

# %%
import numpy as np
import tensorflow as tf
from sklearn.metrics import precision_score, recall_score, accuracy_score, fbeta_score, classification_report


# Function to evaluate the model
def evaluate_model_with_report(model, tokenizer, dataset):
    total_loss = 0
    all_preds = []
    all_labels = []

    with tf.device('/CPU:0'):
        for batch in dataset:
            inputs = batch['input_ids']
            attention_mask = batch['attention_mask']
            batch_labels = batch['labels']

            # Ensure decoder_input_ids are created correctly
            decoder_input_ids = model._shift_right(batch_labels)
            
            outputs = model(input_ids=inputs, attention_mask=attention_mask, decoder_input_ids=decoder_input_ids, labels=batch_labels, training=False)
            loss = outputs.loss

            total_loss += loss.numpy()

            # Decode predictions and true labels
            pred_ids = model.generate(input_ids=inputs, attention_mask=attention_mask)
            preds = [set(tokenizer.decode(ids, skip_special_tokens=True).split(', ')) for ids in pred_ids.numpy()]
            labels = [set(tokenizer.decode(ids, skip_special_tokens=True).split(', ')) for ids in batch_labels.numpy()]

            all_preds.extend(preds)
            all_labels.extend(labels)

    avg_loss = total_loss / len(dataset)

    # Convert to binary format for multi-label evaluation
    unique_labels = list(set([label for sublist in all_labels for label in sublist]))
    label_to_index = {label: i for i, label in enumerate(unique_labels)}
    
    y_true_bin = np.zeros((len(all_labels), len(unique_labels)))
    y_pred_bin = np.zeros((len(all_preds), len(unique_labels)))
    
    for i, labels in enumerate(all_labels):
        for label in labels:
            if label in label_to_index:
                y_true_bin[i, label_to_index[label]] = 1
    
    for i, preds in enumerate(all_preds):
        for pred in preds:
            if pred in label_to_index:
                y_pred_bin[i, label_to_index[pred]] = 1

    precision = precision_score(y_true_bin, y_pred_bin, average='weighted', zero_division=np.nan)
    recall = recall_score(y_true_bin, y_pred_bin, average='weighted', zero_division=np.nan)
    accuracy = accuracy_score(y_true_bin, y_pred_bin)
    fbeta = fbeta_score(y_true_bin, y_pred_bin, beta=0.2, average='weighted', zero_division=np.nan)
    
    # Generate classification report
    report = classification_report(y_true_bin, y_pred_bin, target_names=unique_labels, zero_division=np.nan)
    
    # Add accuracy to the report
    report_with_accuracy = f"Accuracy: {accuracy:.4f}\n\n{report}"

    return avg_loss, precision, recall, accuracy, fbeta, report_with_accuracy

# %%
# Evaluate on the validation dataset
val_loss2, val_precision2, val_recall2, val_accuracy2, val_fbeta2, val_report2 = evaluate_model_with_report(model2, tokenizer2, val_dataset)
print(f"Validation Loss: {val_loss2}, Precision: {val_precision2}, Recall: {val_recall2}, Accuracy: {val_accuracy2}, Fbeta: {val_fbeta2}")
print("Classification Report:\n", val_report2)
# Out:
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:837: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length.  recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Validation Loss: [0.05998851], Precision: 0.8377230771805018, Recall: 0.627039627039627, Accuracy: 0.7276341948310139, Fbeta: 0.8038365351276481
# Classification Report:
#                           precision    recall  f1-score   support
#
#                 renault       0.50      1.00      0.67         1
#                     geo        nan      0.00      0.00         3
#              mitsubishi       1.00      0.42      0.59        12
#                  datsun       1.00      1.00      1.00         2
#                   acura       0.80      0.57      0.67        14
#                  desoto        nan      0.00      0.00         1
#                    saab       0.83      0.62      0.71         8
#                     bmw       1.00      0.89      0.94        27
#                   lexus       1.00      0.62      0.76        13
#                  hummer       1.00      0.40      0.57         5
#                   tesla       1.00      1.00      1.00         1
#                chrysler       0.62      0.62      0.62        24
#                   volvo       0.83      0.83      0.83         6
#                  subaru       0.91      0.91      0.91        11
#              alfa romeo        nan      0.00      0.00         1
#                  daewoo        nan      0.00      0.00         1
#                      mg        nan      0.00      0.00         1
#              studebaker       1.00      1.00      1.00         1
#                 triumph        nan      0.00      0.00         1
#                   dodge       0.81      0.76      0.78        45
#                   honda       0.85      0.65      0.74        26
#                    seat        nan      0.00      0.00         1
#            freightliner       1.00      0.50      0.67         2
#                 peugeot        nan      0.00      0.00         1
#                   lotus        nan      0.00      0.00         1
#                  suzuki       1.00      0.17      0.29         6
#                    mini       1.00      0.67      0.80         3
#                  saturn       0.44      0.44      0.44         9
#              volkswagen       0.80      0.60      0.69        20
#                 lincoln       0.62      0.25      0.36        20
#                   eagle       1.00      0.33      0.50         3
#                    fiat       1.00      0.50      0.67         2
#                     amc       1.00      0.50      0.67         2
#                    jeep       0.83      0.62      0.71        24
#             rolls-royce        nan      0.00      0.00         1
#           mercedes-benz       0.94      0.89      0.92        19
# international harvester       1.00      0.67      0.80         3
#                   scion       1.00      0.17      0.29         6
#                 hyundai       1.00      0.50      0.67        20
#                 genesis        nan      0.00      0.00         1
#              am general        nan      0.00      0.00         1
#               chevrolet       0.91      0.72      0.80        81
#                infiniti       1.00      0.73      0.84        11
#              land rover       1.00      0.80      0.89         5
#                   buick       0.69      0.60      0.64        30
#                   fargo       1.00      1.00      1.00         1
#                    audi       0.93      0.87      0.90        15
#                     ram       0.57      0.50      0.53         8
#                  duplex       1.00      1.00      1.00         1
#                  jensen        nan      0.00      0.00         1
#                   isuzu       0.33      0.18      0.24        11
#             lamborghini        nan      0.00      0.00         1
#                   edsel       1.00      1.00      1.00         1
#               workhorse       1.00      1.00      1.00         1
#          sterling truck       1.00      1.00      1.00         1
#                kenworth       1.00      1.00      1.00         1
#                 checker        nan      0.00      0.00         1
#                  jaguar       1.00      1.00      1.00         4
#                 ferrari       1.00      1.00      1.00         1
#                daihatsu        nan      0.00      0.00         1
#         american motors        nan      0.00      0.00         1
#                    ford       0.86      0.90      0.88        70
#                 mercury       0.70      0.32      0.44        22
#                  nissan       0.96      0.83      0.89        29
#                     kia       0.92      0.71      0.80        17
#                  toyota       1.00      0.67      0.80        36
#                 pontiac       0.75      0.58      0.65        31
#                cadillac       0.80      0.32      0.46        25
#                  merkur        nan      0.00      0.00         1
#                     gmc       0.86      0.61      0.71        49
#              oldsmobile       0.50      0.39      0.44        18
#                   mazda       0.63      0.71      0.67        17
#                 porsche       1.00      0.40      0.57         5
#                plymouth       0.67      0.17      0.27        12
#
#               micro avg       0.84      0.63      0.72       858
#               macro avg       0.87      0.50      0.55       858
#            weighted avg       0.84      0.63      0.70       858
#             samples avg       0.90      0.82      0.83       858
# 2024-08-04 12:48:40.899909: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# Evaluate on the validation dataset
val_loss3, val_precision3, val_recall3, val_accuracy3, val_fbeta3, val_report3 = evaluate_model_with_report(model3, tokenizer3, val_dataset)
print(f"Validation Loss: {val_loss3}, Precision: {val_precision3}, Recall: {val_recall3}, Accuracy: {val_accuracy3}, Fbeta: {val_fbeta3}")
print("Classification Report:\n", val_report3)
# Out:
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:837: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length.  recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Validation Loss: [0.04869421], Precision: 0.7905955033822475, Recall: 0.6165501165501166, Accuracy: 0.6918489065606361, Fbeta: 0.7500269388457076
# Classification Report:
#                           precision    recall  f1-score   support
#
#                 renault       1.00      1.00      1.00         1
#                     geo        nan      0.00      0.00         3
#              mitsubishi       1.00      0.42      0.59        12
#                  datsun       1.00      0.50      0.67         2
#                   acura       1.00      0.50      0.67        14
#                  desoto        nan      0.00      0.00         1
#                    saab       1.00      0.38      0.55         8
#                     bmw       1.00      0.93      0.96        27
#                   lexus       1.00      0.46      0.63        13
#                  hummer        nan      0.00      0.00         5
#                   tesla       1.00      1.00      1.00         1
#                chrysler       0.88      0.62      0.73        24
#                   volvo       1.00      0.83      0.91         6
#                  subaru       1.00      0.82      0.90        11
#              alfa romeo        nan      0.00      0.00         1
#                  daewoo        nan      0.00      0.00         1
#                      mg       1.00      1.00      1.00         1
#              studebaker       1.00      1.00      1.00         1
#                 triumph        nan      0.00      0.00         1
#                   dodge       0.89      0.69      0.78        45
#                   honda       0.86      0.69      0.77        26
#                    seat        nan      0.00      0.00         1
#            freightliner       1.00      0.50      0.67         2
#                 peugeot        nan      0.00      0.00         1
#                   lotus        nan      0.00      0.00         1
#                  suzuki       1.00      0.17      0.29         6
#                    mini       1.00      0.67      0.80         3
#                  saturn       0.67      0.22      0.33         9
#              volkswagen       0.91      0.50      0.65        20
#                 lincoln       0.80      0.20      0.32        20
#                   eagle        nan      0.00      0.00         3
#                    fiat       1.00      1.00      1.00         2
#                     amc        nan      0.00      0.00         2
#                    jeep       0.88      0.62      0.73        24
#             rolls-royce        nan      0.00      0.00         1
#           mercedes-benz       1.00      0.89      0.94        19
# international harvester       1.00      0.67      0.80         3
#                   scion       0.50      0.17      0.25         6
#                 hyundai       1.00      0.50      0.67        20
#                 genesis        nan      0.00      0.00         1
#              am general        nan      0.00      0.00         1
#               chevrolet       0.74      0.79      0.77        81
#                infiniti       0.89      0.73      0.80        11
#              land rover       1.00      0.80      0.89         5
#                   buick       0.43      0.67      0.53        30
#                   fargo       1.00      1.00      1.00         1
#                    audi       1.00      0.80      0.89        15
#                     ram       0.50      0.25      0.33         8
#                  duplex       1.00      1.00      1.00         1
#                  jensen        nan      0.00      0.00         1
#                   isuzu       0.67      0.18      0.29        11
#             lamborghini        nan      0.00      0.00         1
#                   edsel       1.00      1.00      1.00         1
#               workhorse       1.00      1.00      1.00         1
#          sterling truck       1.00      1.00      1.00         1
#                kenworth       1.00      1.00      1.00         1
#                 checker        nan      0.00      0.00         1
#                  jaguar       1.00      1.00      1.00         4
#                 ferrari       1.00      1.00      1.00         1
#                daihatsu        nan      0.00      0.00         1
#         american motors       0.00      0.00      0.00         1
#                    ford       0.74      0.87      0.80        70
#                 mercury       0.24      0.32      0.27        22
#                  nissan       0.92      0.83      0.87        29
#                     kia       1.00      0.76      0.87        17
#                  toyota       1.00      0.67      0.80        36
#                 pontiac       0.41      0.55      0.47        31
#                cadillac       0.78      0.28      0.41        25
#                  merkur        nan      0.00      0.00         1
#                     gmc       0.60      0.73      0.66        49
#              oldsmobile       0.71      0.28      0.40        18
#                   mazda       0.38      0.71      0.49        17
#                 porsche       1.00      0.40      0.57         5
#                plymouth       0.67      0.17      0.27        12
#
#               micro avg       0.74      0.62      0.67       858
#               macro avg       0.86      0.48      0.53       858
#            weighted avg       0.79      0.62      0.65       858
#             samples avg       0.86      0.80      0.82       858

# %%
# Evaluate on the validation dataset
val_loss4, val_precision4, val_recall4, val_accuracy4, val_fbeta4, val_report4 = evaluate_model_with_report(model4, tokenizer4, val_dataset)
print(f"Validation Loss: {val_loss4}, Precision: {val_precision4}, Recall: {val_recall4}, Accuracy: {val_accuracy4}, Fbeta: {val_fbeta4}")
print("Classification Report:\n", val_report4)
# Out:
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:837: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length.  recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Validation Loss: [0.01674004], Precision: 0.8116222228327404, Recall: 0.6596736596736597, Accuracy: 0.7475149105367793, Fbeta: 0.7801629621126409
# Classification Report:
#  Accuracy: 0.7475
#
#                          precision    recall  f1-score   support
#
#                 renault       1.00      1.00      1.00         1
#                     geo        nan      0.00      0.00         3
#              mitsubishi       1.00      0.50      0.67        12
#                  datsun       1.00      0.50      0.67         2
#                   acura       0.64      0.64      0.64        14
#                  desoto        nan      0.00      0.00         1
#                    saab       1.00      0.38      0.55         8
#                     bmw       1.00      0.89      0.94        27
#                   lexus       1.00      0.46      0.63        13
#                  hummer       0.00      0.00      0.00         5
#                   tesla       1.00      1.00      1.00         1
#                chrysler       0.74      0.58      0.65        24
#                   volvo       1.00      0.83      0.91         6
#                  subaru       1.00      0.91      0.95        11
#              alfa romeo       1.00      1.00      1.00         1
#                  daewoo        nan      0.00      0.00         1
#                      mg       1.00      1.00      1.00         1
#              studebaker       1.00      1.00      1.00         1
#                 triumph        nan      0.00      0.00         1
#                   dodge       0.91      0.69      0.78        45
#                   honda       0.75      0.69      0.72        26
#                    seat        nan      0.00      0.00         1
#            freightliner       1.00      0.50      0.67         2
#                 peugeot        nan      0.00      0.00         1
#                   lotus        nan      0.00      0.00         1
#                  suzuki       1.00      0.17      0.29         6
#                    mini       1.00      0.67      0.80         3
#                  saturn       1.00      0.33      0.50         9
#              volkswagen       1.00      0.60      0.75        20
#                 lincoln       0.55      0.60      0.57        20
#                   eagle       1.00      0.33      0.50         3
#                    fiat       1.00      1.00      1.00         2
#                     amc       1.00      0.50      0.67         2
#                    jeep       0.94      0.62      0.75        24
#             rolls-royce        nan      0.00      0.00         1
#           mercedes-benz       1.00      0.89      0.94        19
# international harvester       1.00      1.00      1.00         3
#                   scion       1.00      0.33      0.50         6
#                 hyundai       1.00      0.45      0.62        20
#                 genesis        nan      0.00      0.00         1
#              am general        nan      0.00      0.00         1
#               chevrolet       0.68      0.94      0.79        81
#                infiniti       1.00      0.82      0.90        11
#              land rover       1.00      0.80      0.89         5
#                   buick       0.36      0.83      0.51        30
#                   fargo       1.00      1.00      1.00         1
#                    audi       0.87      0.87      0.87        15
#                     ram       0.67      0.50      0.57         8
#                  duplex       1.00      1.00      1.00         1
#                  jensen        nan      0.00      0.00         1
#                   isuzu       0.18      0.55      0.27        11
#             lamborghini        nan      0.00      0.00         1
#                   edsel       1.00      1.00      1.00         1
#               workhorse       1.00      1.00      1.00         1
#          sterling truck       1.00      1.00      1.00         1
#                kenworth       1.00      1.00      1.00         1
#                 checker        nan      0.00      0.00         1
#                  jaguar       1.00      1.00      1.00         4
#                 ferrari       1.00      1.00      1.00         1
#                daihatsu        nan      0.00      0.00         1
#         american motors        nan      0.00      0.00         1
#                    ford       0.88      0.86      0.87        70
#                 mercury       0.48      0.45      0.47        22
#                  nissan       0.89      0.83      0.86        29
#                     kia       0.93      0.76      0.84        17
#                  toyota       0.96      0.67      0.79        36
#                 pontiac       0.36      0.61      0.45        31
#                cadillac       0.60      0.36      0.45        25
#                  merkur        nan      0.00      0.00         1
#                     gmc       0.86      0.49      0.62        49
#              oldsmobile       1.00      0.28      0.43        18
#                   mazda       1.00      0.71      0.83        17
#                 porsche       1.00      0.60      0.75         5
#                plymouth       1.00      0.17      0.29        12
#
#               micro avg       0.73      0.66      0.69       858
#               macro avg       0.88      0.54      0.58       858
#            weighted avg       0.81      0.66      0.69       858
#             samples avg       0.88      0.84      0.84       858

# %%
# Evaluate on the validation dataset
val_loss5, val_precision5, val_recall5, val_accuracy5, val_fbeta5, val_report5 = evaluate_model_with_report(model5, tokenizer5, val_dataset)
print(f"Validation Loss: {val_loss5}, Precision: {val_precision5}, Recall: {val_recall5}, Accuracy: {val_accuracy5}, Fbeta: {val_fbeta5}")
print("Classification Report:\n", val_report5)
# Out:
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:837: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length.  recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Validation Loss: [0.01347506], Precision: 0.8476508115962548, Recall: 0.6853146853146853, Accuracy: 0.7713717693836978, Fbeta: 0.8144640016475208
# Classification Report:
#  Accuracy: 0.7714
#
#                          precision    recall  f1-score   support
#
#                 renault       0.50      1.00      0.67         1
#                     geo        nan      0.00      0.00         3
#              mitsubishi       1.00      0.50      0.67        12
#                  datsun       1.00      0.50      0.67         2
#                   acura       0.91      0.71      0.80        14
#                  desoto        nan      0.00      0.00         1
#                    saab       1.00      0.38      0.55         8
#                     bmw       1.00      0.89      0.94        27
#                   lexus       1.00      0.46      0.63        13
#                  hummer        nan      0.00      0.00         5
#                   tesla       1.00      1.00      1.00         1
#                chrysler       0.82      0.58      0.68        24
#                   volvo       1.00      0.83      0.91         6
#                  subaru       1.00      0.91      0.95        11
#              alfa romeo       1.00      1.00      1.00         1
#                  daewoo        nan      0.00      0.00         1
#                      mg       1.00      1.00      1.00         1
#              studebaker       1.00      1.00      1.00         1
#                 triumph        nan      0.00      0.00         1
#                   dodge       0.92      0.73      0.81        45
#                   honda       0.83      0.77      0.80        26
#                    seat        nan      0.00      0.00         1
#            freightliner       1.00      0.50      0.67         2
#                 peugeot        nan      0.00      0.00         1
#                   lotus        nan      0.00      0.00         1
#                  suzuki       1.00      0.17      0.29         6
#                    mini       1.00      0.67      0.80         3
#                  saturn       0.60      0.33      0.43         9
#              volkswagen       0.87      0.65      0.74        20
#                 lincoln       0.86      0.60      0.71        20
#                   eagle       1.00      0.33      0.50         3
#                    fiat       1.00      1.00      1.00         2
#                     amc       1.00      0.50      0.67         2
#                    jeep       1.00      0.71      0.83        24
#             rolls-royce        nan      0.00      0.00         1
#           mercedes-benz       1.00      0.89      0.94        19
# international harvester       1.00      1.00      1.00         3
#                   scion       1.00      0.33      0.50         6
#                 hyundai       0.87      0.65      0.74        20
#                 genesis       1.00      1.00      1.00         1
#              am general        nan      0.00      0.00         1
#               chevrolet       0.82      0.94      0.87        81
#                infiniti       1.00      0.82      0.90        11
#              land rover       1.00      0.80      0.89         5
#                   buick       0.48      0.73      0.58        30
#                   fargo       1.00      1.00      1.00         1
#                    audi       0.93      0.87      0.90        15
#                     ram       0.67      0.50      0.57         8
#                  duplex       1.00      1.00      1.00         1
#                  jensen        nan      0.00      0.00         1
#                   isuzu       0.80      0.36      0.50        11
#             lamborghini        nan      0.00      0.00         1
#                   edsel       1.00      1.00      1.00         1
#               workhorse       1.00      1.00      1.00         1
#          sterling truck       1.00      1.00      1.00         1
#                kenworth       1.00      1.00      1.00         1
#                 checker        nan      0.00      0.00         1
#                  jaguar       0.80      1.00      0.89         4
#                 ferrari       1.00      1.00      1.00         1
#                daihatsu        nan      0.00      0.00         1
#         american motors        nan      0.00      0.00         1
#                    ford       0.86      0.89      0.87        70
#                 mercury       0.50      0.55      0.52        22
#                  nissan       0.96      0.79      0.87        29
#                     kia       0.76      0.76      0.76        17
#                  toyota       1.00      0.69      0.82        36
#                 pontiac       0.53      0.68      0.59        31
#                cadillac       0.67      0.32      0.43        25
#                  merkur        nan      0.00      0.00         1
#                     gmc       0.90      0.57      0.70        49
#              oldsmobile       0.80      0.44      0.57        18
#                   mazda       0.59      0.76      0.67        17
#                 porsche       1.00      0.60      0.75         5
#                plymouth       1.00      0.25      0.40        12
#
#               micro avg       0.82      0.69      0.75       858
#               macro avg       0.90      0.57      0.61       858
#            weighted avg       0.85      0.69      0.73       858
#             samples avg       0.90      0.86      0.87       858

# %% [markdown]
# # Evaluate Test Set

# %%
# Evaluate the model on the test set
avg_loss, precision, recall, accuracy, fbeta, report = evaluate_model_with_report(model2, tokenizer2, test_dataset)
print(f"Test Loss: {avg_loss}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"Accuracy: {accuracy}")
print(f"F-beta Score: {fbeta}")
print("Classification Report with Accuracy:\n", report)
# Out:
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:837: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length.  recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Test Loss: [0.06417125]
# Precision: 0.7945594479708957
# Recall: 0.5948174322732627
# Accuracy: 0.666
# F-beta Score: 0.7628654683468066
# Classification Report with Accuracy:
#  Accuracy: 0.6660
#
#                          precision    recall  f1-score   support
#
#                 renault        nan      0.00      0.00         1
#                     geo       1.00      0.33      0.50         3
#              mitsubishi       0.67      0.50      0.57        12
#                  datsun       0.00      0.00      0.00         1
#                   acura       0.88      0.50      0.64        14
#                  desoto        nan      0.00      0.00         1
#                    saab       0.60      0.38      0.46         8
#                     bmw       1.00      0.89      0.94        27
#                   lexus       1.00      0.58      0.74        12
#                  hummer       0.75      0.60      0.67         5
#                   tesla       1.00      1.00      1.00         2
#                chrysler       0.53      0.38      0.44        24
#                   volvo       1.00      1.00      1.00         6
#                     vpg        nan      0.00      0.00         1
#                  subaru       1.00      0.60      0.75        10
#                      mg        nan      0.00      0.00         1
#                  daewoo       1.00      1.00      1.00         1
#              alfa romeo       1.00      1.00      1.00         1
#               de tomaso        nan      0.00      0.00         1
#                 triumph        nan      0.00      0.00         1
#              studebaker        nan      0.00      0.00         1
#                   dodge       0.67      0.71      0.69        45
#                   honda       0.81      0.50      0.62        26
#                 peugeot        nan      0.00      0.00         1
#            freightliner       1.00      0.50      0.67         2
#                    mini       1.00      1.00      1.00         3
#                  suzuki       1.00      0.67      0.80         6
#                  saturn       0.75      0.67      0.71         9
#              volkswagen       1.00      0.65      0.79        20
#                 lincoln       0.67      0.50      0.57        20
#                   eagle       0.00      0.00      0.00         3
#                    fiat        nan      0.00      0.00         2
#                     amc        nan      0.00      0.00         2
#                    jeep       0.76      0.67      0.71        24
#                   scion       1.00      0.33      0.50         6
# international harvester       1.00      0.67      0.80         3
#           mercedes-benz       0.94      0.79      0.86        19
#             rolls-royce        nan      0.00      0.00         1
#                 hyundai       1.00      0.53      0.69        19
#                 genesis        nan      0.00      0.00         1
#              am general        nan      0.00      0.00         1
#               chevrolet       0.98      0.59      0.74        81
#                infiniti       0.88      0.64      0.74        11
#              land rover       1.00      0.60      0.75         5
#                   buick       0.55      0.57      0.56        30
#                   fargo       1.00      1.00      1.00         1
#                     ram       0.33      0.38      0.35         8
#                    audi       0.92      0.80      0.86        15
#                 sunbeam        nan      0.00      0.00         1
#                  jensen        nan      0.00      0.00         1
#                   isuzu       0.24      0.36      0.29        11
#               workhorse        nan      0.00      0.00         1
#          sterling truck       1.00      1.00      1.00         1
#                kenworth       1.00      1.00      1.00         1
#                 checker        nan      0.00      0.00         1
#                  jaguar       1.00      0.50      0.67         4
#                daihatsu        nan      0.00      0.00         1
#                    ford       0.68      0.86      0.76        70
#                  toyota       0.97      0.78      0.86        36
#                 mercury       0.77      0.45      0.57        22
#                     kia       1.00      0.41      0.58        17
#                  nissan       0.83      0.69      0.75        29
#                 pontiac       0.85      0.35      0.50        31
#                cadillac       0.70      0.28      0.40        25
#                     gmc       0.74      0.69      0.72        49
#              oldsmobile       0.42      0.44      0.43        18
#                   mazda       0.65      0.65      0.65        17
#                 porsche       1.00      0.80      0.89         5
#                plymouth       0.75      0.27      0.40        11
#
#               micro avg       0.76      0.59      0.67       849
#               macro avg       0.81      0.45      0.50       849
#            weighted avg       0.79      0.59      0.66       849
#             samples avg       0.84      0.76      0.78       849

# %%
# Evaluate the model on the test set
avg_loss, precision, recall, accuracy, fbeta, report = evaluate_model_with_report(model3, tokenizer3, test_dataset)
print(f"Test Loss: {avg_loss}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"Accuracy: {accuracy}")
print(f"F-beta Score: {fbeta}")
print("Classification Report with Accuracy:\n", report)
# Out:
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:837: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length.  recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Test Loss: [0.05161441]
# Precision: 0.773308569203846
# Recall: 0.6018845700824499
# Accuracy: 0.654
# F-beta Score: 0.7361419631351723
# Classification Report with Accuracy:
#  Accuracy: 0.6540
#
#                          precision    recall  f1-score   support
#
#                 renault        nan      0.00      0.00         1
#                     geo       1.00      0.33      0.50         3
#              mitsubishi       0.88      0.58      0.70        12
#                  datsun        nan      0.00      0.00         1
#                   acura       1.00      0.50      0.67        14
#                  desoto        nan      0.00      0.00         1
#                    saab       1.00      0.25      0.40         8
#                     bmw       1.00      0.89      0.94        27
#                   lexus       0.80      0.67      0.73        12
#                  hummer       1.00      0.20      0.33         5
#                   tesla       1.00      1.00      1.00         2
#                chrysler       0.57      0.33      0.42        24
#                   volvo       1.00      0.83      0.91         6
#                     vpg        nan      0.00      0.00         1
#                  subaru       1.00      0.60      0.75        10
#                      mg        nan      0.00      0.00         1
#                  daewoo       1.00      1.00      1.00         1
#              alfa romeo       1.00      1.00      1.00         1
#               de tomaso        nan      0.00      0.00         1
#                 triumph        nan      0.00      0.00         1
#              studebaker        nan      0.00      0.00         1
#                   dodge       0.79      0.58      0.67        45
#                   honda       0.93      0.54      0.68        26
#                 peugeot        nan      0.00      0.00         1
#            freightliner       1.00      0.50      0.67         2
#                    mini       1.00      1.00      1.00         3
#                  suzuki       1.00      0.50      0.67         6
#                  saturn       1.00      0.44      0.62         9
#              volkswagen       1.00      0.60      0.75        20
#                 lincoln       0.73      0.55      0.63        20
#                   eagle        nan      0.00      0.00         3
#                    fiat        nan      0.00      0.00         2
#                     amc        nan      0.00      0.00         2
#                    jeep       0.87      0.54      0.67        24
#                   scion       1.00      0.33      0.50         6
# international harvester       1.00      0.67      0.80         3
#           mercedes-benz       0.94      0.79      0.86        19
#             rolls-royce        nan      0.00      0.00         1
#                 hyundai       1.00      0.53      0.69        19
#                 genesis        nan      0.00      0.00         1
#              am general        nan      0.00      0.00         1
#               chevrolet       0.73      0.74      0.74        81
#                infiniti       1.00      0.55      0.71        11
#              land rover       1.00      0.60      0.75         5
#                   buick       0.37      0.57      0.45        30
#                   fargo       1.00      1.00      1.00         1
#                     ram       0.33      0.12      0.18         8
#                    audi       0.87      0.87      0.87        15
#                 sunbeam        nan      0.00      0.00         1
#                  jensen        nan      0.00      0.00         1
#                   isuzu       1.00      0.18      0.31        11
#               workhorse        nan      0.00      0.00         1
#          sterling truck       1.00      1.00      1.00         1
#                kenworth       1.00      1.00      1.00         1
#                 checker        nan      0.00      0.00         1
#                  jaguar       1.00      0.50      0.67         4
#                daihatsu        nan      0.00      0.00         1
#                    ford       0.66      0.84      0.74        70
#                  toyota       0.97      0.78      0.86        36
#                 mercury       0.26      0.50      0.34        22
#                     kia       0.89      0.47      0.62        17
#                  nissan       0.96      0.76      0.85        29
#                 pontiac       0.33      0.42      0.37        31
#                cadillac       0.75      0.24      0.36        25
#                     gmc       0.56      0.80      0.66        49
#              oldsmobile       1.00      0.50      0.67        18
#                   mazda       0.38      0.76      0.51        17
#                 porsche       1.00      0.80      0.89         5
#                plymouth       1.00      0.27      0.43        11
#
#               micro avg       0.70      0.60      0.65       849
#               macro avg       0.87      0.44      0.49       849
#            weighted avg       0.77      0.60      0.64       849
#             samples avg       0.84      0.76      0.78       849

# %%
# Evaluate the model on the test set
avg_loss, precision, recall, accuracy, fbeta, report = evaluate_model_with_report(model4, tokenizer4, test_dataset)
print(f"Test Loss: {avg_loss}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"Accuracy: {accuracy}")
print(f"F-beta Score: {fbeta}")
print("Classification Report with Accuracy:\n", report)
# Out:
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:837: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length.  recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Test Loss: [0.0177298]
# Precision: 0.7562733613202286
# Recall: 0.6348645465253239
# Accuracy: 0.678
# F-beta Score: 0.7222478438589839
# Classification Report with Accuracy:
#  Accuracy: 0.6780
#
#                          precision    recall  f1-score   support
#
#                 renault        nan      0.00      0.00         1
#                     geo        nan      0.00      0.00         3
#              mitsubishi       1.00      0.67      0.80        12
#                  datsun        nan      0.00      0.00         1
#                   acura       0.52      0.79      0.63        14
#                  desoto        nan      0.00      0.00         1
#                    saab       1.00      0.25      0.40         8
#                     bmw       1.00      0.89      0.94        27
#                   lexus       0.89      0.67      0.76        12
#                  hummer       1.00      0.40      0.57         5
#                   tesla       1.00      1.00      1.00         2
#                chrysler       0.63      0.50      0.56        24
#                   volvo       1.00      0.83      0.91         6
#                     vpg        nan      0.00      0.00         1
#                  subaru       1.00      0.70      0.82        10
#                      mg        nan      0.00      0.00         1
#                  daewoo       1.00      1.00      1.00         1
#              alfa romeo       1.00      1.00      1.00         1
#               de tomaso        nan      0.00      0.00         1
#                 triumph        nan      0.00      0.00         1
#              studebaker        nan      0.00      0.00         1
#                   dodge       0.79      0.69      0.74        45
#                   honda       0.55      0.62      0.58        26
#                 peugeot        nan      0.00      0.00         1
#            freightliner       1.00      0.50      0.67         2
#                    mini       1.00      1.00      1.00         3
#                  suzuki       1.00      0.50      0.67         6
#                  saturn       1.00      0.44      0.62         9
#              volkswagen       1.00      0.70      0.82        20
#                 lincoln       0.50      0.75      0.60        20
#                   eagle        nan      0.00      0.00         3
#                    fiat        nan      0.00      0.00         2
#                     amc        nan      0.00      0.00         2
#                    jeep       0.83      0.62      0.71        24
#                   scion       0.75      0.50      0.60         6
# international harvester       1.00      0.67      0.80         3
#           mercedes-benz       0.94      0.79      0.86        19
#             rolls-royce        nan      0.00      0.00         1
#                 hyundai       0.91      0.53      0.67        19
#                 genesis        nan      0.00      0.00         1
#              am general        nan      0.00      0.00         1
#               chevrolet       0.67      0.86      0.75        81
#                infiniti       1.00      0.55      0.71        11
#              land rover       1.00      0.60      0.75         5
#                   buick       0.31      0.73      0.43        30
#                   fargo       1.00      1.00      1.00         1
#                     ram       0.50      0.25      0.33         8
#                    audi       0.81      0.87      0.84        15
#                 sunbeam        nan      0.00      0.00         1
#                  jensen        nan      0.00      0.00         1
#                   isuzu       0.16      0.45      0.24        11
#               workhorse        nan      0.00      0.00         1
#          sterling truck       1.00      1.00      1.00         1
#                kenworth       1.00      1.00      1.00         1
#                 checker        nan      0.00      0.00         1
#                  jaguar       1.00      0.50      0.67         4
#                daihatsu        nan      0.00      0.00         1
#                    ford       0.76      0.83      0.79        70
#                  toyota       1.00      0.75      0.86        36
#                 mercury       0.36      0.59      0.45        22
#                     kia       0.73      0.47      0.57        17
#                  nissan       0.77      0.79      0.78        29
#                 pontiac       0.33      0.48      0.39        31
#                cadillac       0.70      0.28      0.40        25
#                     gmc       0.92      0.45      0.60        49
#              oldsmobile       1.00      0.39      0.56        18
#                   mazda       0.92      0.65      0.76        17
#                 porsche       1.00      0.80      0.89         5
#                plymouth       0.60      0.27      0.38        11
#
#               micro avg       0.67      0.63      0.65       849
#               macro avg       0.83      0.46      0.49       849
#            weighted avg       0.76      0.63      0.65       849
#             samples avg       0.84      0.80      0.79       849

# %%
# Evaluate the model on the test set
avg_loss, precision, recall, accuracy, fbeta, report = evaluate_model_with_report(model5, tokenizer5, test_dataset)
print(f"Test Loss: {avg_loss}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"Accuracy: {accuracy}")
print(f"F-beta Score: {fbeta}")
print("Classification Report with Accuracy:\n", report)
# Out:
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:837: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length.  recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Test Loss: [0.01306892]
# Precision: 0.8053516509328672
# Recall: 0.6725559481743227
# Accuracy: 0.708
# F-beta Score: 0.7807955459845115
# Classification Report with Accuracy:
#  Accuracy: 0.7080
#
#                          precision    recall  f1-score   support
#
#                 renault        nan      0.00      0.00         1
#                     geo       1.00      0.33      0.50         3
#              mitsubishi       0.89      0.67      0.76        12
#                  datsun       1.00      1.00      1.00         1
#                   acura       0.60      0.64      0.62        14
#                  desoto        nan      0.00      0.00         1
#                    saab       1.00      0.38      0.55         8
#                     bmw       1.00      0.89      0.94        27
#                   lexus       0.90      0.75      0.82        12
#                  hummer       1.00      0.40      0.57         5
#                   tesla       1.00      1.00      1.00         2
#                chrysler       0.59      0.42      0.49        24
#                   volvo       1.00      0.83      0.91         6
#                     vpg       1.00      1.00      1.00         1
#                  subaru       1.00      0.70      0.82        10
#                      mg        nan      0.00      0.00         1
#                  daewoo       1.00      1.00      1.00         1
#              alfa romeo       1.00      1.00      1.00         1
#               de tomaso        nan      0.00      0.00         1
#                 triumph        nan      0.00      0.00         1
#              studebaker        nan      0.00      0.00         1
#                   dodge       0.83      0.76      0.79        45
#                   honda       0.56      0.69      0.62        26
#                 peugeot        nan      0.00      0.00         1
#            freightliner       1.00      0.50      0.67         2
#                    mini       1.00      1.00      1.00         3
#                  suzuki       1.00      0.67      0.80         6
#                  saturn       0.57      0.44      0.50         9
#              volkswagen       0.88      0.70      0.78        20
#                 lincoln       0.74      0.85      0.79        20
#                   eagle       0.00      0.00      0.00         3
#                    fiat        nan      0.00      0.00         2
#                     amc       1.00      0.50      0.67         2
#                    jeep       0.89      0.67      0.76        24
#                   scion       1.00      0.50      0.67         6
# international harvester       1.00      0.67      0.80         3
#           mercedes-benz       0.94      0.84      0.89        19
#             rolls-royce        nan      0.00      0.00         1
#                 hyundai       0.75      0.63      0.69        19
#                 genesis        nan      0.00      0.00         1
#              am general        nan      0.00      0.00         1
#               chevrolet       0.81      0.86      0.84        81
#                infiniti       1.00      0.64      0.78        11
#              land rover       1.00      0.80      0.89         5
#                   buick       0.48      0.77      0.59        30
#                   fargo       1.00      1.00      1.00         1
#                     ram       0.80      0.50      0.62         8
#                    audi       0.87      0.87      0.87        15
#                 sunbeam        nan      0.00      0.00         1
#                  jensen        nan      0.00      0.00         1
#                   isuzu       0.67      0.36      0.47        11
#               workhorse        nan      0.00      0.00         1
#          sterling truck       1.00      1.00      1.00         1
#                kenworth       1.00      1.00      1.00         1
#                 checker        nan      0.00      0.00         1
#                  jaguar       1.00      0.50      0.67         4
#                daihatsu        nan      0.00      0.00         1
#                    ford       0.91      0.87      0.89        70
#                  toyota       1.00      0.72      0.84        36
#                 mercury       0.67      0.73      0.70        22
#                     kia       0.65      0.65      0.65        17
#                  nissan       0.96      0.79      0.87        29
#                 pontiac       0.45      0.58      0.51        31
#                cadillac       0.64      0.28      0.39        25
#                     gmc       0.90      0.53      0.67        49
#              oldsmobile       0.75      0.33      0.46        18
#                   mazda       0.73      0.65      0.69        17
#                 porsche       1.00      0.80      0.89         5
#                plymouth       0.75      0.27      0.40        11
#
#               micro avg       0.78      0.67      0.72       849
#               macro avg       0.85      0.52      0.57       849
#            weighted avg       0.81      0.67      0.71       849
#             samples avg       0.87      0.82      0.83       849

# %% [markdown]
# ## Evaluate Model Performance

# %%
import numpy as np
import tensorflow as tf
from sklearn.metrics import precision_score, recall_score, accuracy_score, fbeta_score

def evaluate_metrics(model, tokenizer, dataset):
    try:
        return _evaluate_metrics_on_device(model, tokenizer, dataset, device='/GPU:0')
    except:
        print("Error encountered on GPU, falling back to CPU.")
        return _evaluate_metrics_on_device(model, tokenizer, dataset, device='/CPU:0')

def _evaluate_metrics_on_device(model, tokenizer, dataset, device):
    total_loss = 0
    all_preds = []
    all_labels = []

    with tf.device(device):
        for batch in dataset:
            inputs = batch['input_ids']
            attention_mask = batch['attention_mask']
            batch_labels = batch['labels']

            # Ensure decoder_input_ids are created correctly
            decoder_input_ids = model._shift_right(batch_labels)
            
            outputs = model(input_ids=inputs, attention_mask=attention_mask, decoder_input_ids=decoder_input_ids, labels=batch_labels, training=False)
            loss = outputs.loss

            total_loss += loss.numpy()

            # Decode predictions and true labels
            pred_ids = model.generate(input_ids=inputs, attention_mask=attention_mask)
            preds = [set(tokenizer.decode(ids, skip_special_tokens=True).split(', ')) for ids in pred_ids.numpy()]
            labels = [set(tokenizer.decode(ids, skip_special_tokens=True).split(', ')) for ids in batch_labels.numpy()]

            all_preds.extend(preds)
            all_labels.extend(labels)

    avg_loss = total_loss / len(dataset)

    # Convert to binary format for multi-label evaluation
    unique_labels = list(set([label for sublist in all_labels for label in sublist]))
    label_to_index = {label: i for i, label in enumerate(unique_labels)}
    
    y_true_bin = np.zeros((len(all_labels), len(unique_labels)))
    y_pred_bin = np.zeros((len(all_preds), len(unique_labels)))
    
    for i, labels in enumerate(all_labels):
        for label in labels:
            if label in label_to_index:
                y_true_bin[i, label_to_index[label]] = 1
    
    for i, preds in enumerate(all_preds):
        for pred in preds:
            if pred in label_to_index:
                y_pred_bin[i, label_to_index[pred]] = 1

    precision = precision_score(y_true_bin, y_pred_bin, average='weighted', zero_division=np.nan)
    recall = recall_score(y_true_bin, y_pred_bin, average='weighted', zero_division=np.nan)
    accuracy = accuracy_score(y_true_bin, y_pred_bin)
    fbeta = fbeta_score(y_true_bin, y_pred_bin, beta=0.2, average='weighted', zero_division=np.nan)
    
    return avg_loss, precision, recall, accuracy, fbeta

# %% [markdown]
# # Create Test Predictions

# %%
# Function to generate predictions on the test set
def generate_predictions(model, tokenizer, dataset):
    all_descriptions = []
    all_labels = []
    all_predictions = []

    with tf.device('/CPU:0'):
        for batch in dataset:
            inputs = batch['input_ids']
            attention_mask = batch['attention_mask']
            batch_labels = batch['labels']

            # Ensure decoder_input_ids are created correctly
            decoder_input_ids = model._shift_right(batch_labels)
            
            # Generate predictions
            pred_ids = model.generate(input_ids=inputs, attention_mask=attention_mask)
            preds = [tokenizer.decode(ids, skip_special_tokens=True) for ids in pred_ids.numpy()]
            labels = [tokenizer.decode(ids, skip_special_tokens=True) for ids in batch_labels.numpy()]
            descriptions = [tokenizer.decode(ids, skip_special_tokens=True) for ids in inputs.numpy()]

            all_descriptions.extend(descriptions)
            all_labels.extend(labels)
            all_predictions.extend(preds)

    # Create a DataFrame with the results
    df = pd.DataFrame({
        'Description': all_descriptions,
        'Labels': all_labels,
        'Predictions': all_predictions
    })

    return df

# Generate predictions on the test set
preds_df = generate_predictions(model2, tokenizer2, test_dataset)

print(preds_df.head())
# Out:
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:837: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length.  recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
#   Description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           \
# 0                                                                                       brand: ["caili's company"], make: mazda, model: 3, year: ['2010'], fitment: ['direct replacement'], type: ['seal'], manufacturer part number: ['g560-25-744'], part title: ['original equip data g560-25-744'], part brands: ['original equipment data'], subtype: ['drive axle shaft oil slinger'], part types: ['axle shaft'], category: 4.0, item_title: g560-25-744 for 2010 mazda 3 bl transaxle case half shaft oil seal
# 1  brand: ['2006 mini mini cooper stock number: 00017948'], make: mini, model: mini cooper, year: ['2006', '2006'], fitment: ['direct replacement'], manufacturer part number: ['quality,oem,recycled,part,1-year,3-year_ &,lifetime,warranties', 'true', 'alternator'], sku: ['00017948'], category: 0.0, item_title: 2006 mini cooper alternator 96k 957948, cleaned_desc: powered by frooition about us shipping returns contact us payment faq shop categories all categories helpful links add to favorite sel...
# 2  brand: ['4 seasons', 'fan motor', 'four seasons'], model: four, year: ['1995', '1996', '1997', '1998', '1999', '2000', '2001'], type: ['motor only', 'oe mount', '4 pole'], manufacturer part number: ['35161'], part title: ['exhaust pipe flange gasket walker 35161', 'exhaust header-base, gas, natural 35161 fits 77-78 pontiac firebird 6.6l-v8', 'exhaust tail pipe tip magnaflow ny 35161', 'carquest/fel-pro 35161 gaskets and sealing systems - engine water pump gasket', 'engine cooling fan motor u...
# 3                                           brand: ['4 seasons', 'four seasons'], make: hyundai kia, model: sonata optima, year: ['2013', '2011', '2012', '2014', '2013', '2011', '2012', '2014', '2011', '2012', '2013', '2014'], oem part number: ['bp37m5'], product name: ['auxiliary fan assembly'], manufacturer part number: ['radiator fan assembly. -- usa built', 'bp37m5'], sku: ['400:bp37m5'], category: 1.0, item_title: auxiliary fan assembly for 11-14 hyundai kia sonata optima 24l 4 cyl gas bp37m5
# 4  brand: ['4 seasons', 'four seasons'], type: ['a/c clutch control relay harness connector'], oem part number: ['89051437'], manufacturer part number: ['37220'], sku: ['fs:37220'], part title: ['power steering pressure line hose assembly gates 37220', 'icp/cpi 37220', 'disc brake rotor set-vented sport cross-drilled (pair) brembo 37220', 'auto extra 37220', 'advance 37220 shock absorber', 'a/c clutch control relay harness connector cooling depot 37220', 'auto plus/monroe/expert series 37220 - ...
#
#   Labels                                                     Predictions
# 0                                                      mazda            mazda
# 1                                                       mini             mini
# 2                                                       jeep             jeep
# 3                                               kia, hyundai          hyundai
# 4  chevrolet, buick, pontiac, cadillac, chrysler, oldsmobile  dodge, chrysler

# %%
# Adjust pandas display settings for better readability
pd.set_option('display.max_colwidth', 500)  # Adjust the value to control the width of each column
pd.set_option('display.colheader_justify', 'left')  # Justify column headers to the left
predictions_df = preds_df.copy()
print(predictions_df.shape)
predictions_df.head(50)
# Out:
# (3, 4)
#   Description                              Labels                    Predictions        has_desc
# 0     This is a sample cleaned_desc: item1          [label1, label2]  [label1, label3]  1
# 1  Another description without the keyword                  [label3]  [label2, label3]  0
# 2         This one has cleaned_desc: item2  [label2, label3, label4]  [label4, label2]  1

# %%
predictions_df[['Predictions']].to_csv('pretrained_y_preds.csv', index=False)

# %% [markdown]
# ## Classification Report

# %%
import pandas as pd
from sklearn.metrics import classification_report

def create_classification_report_dataframe(model, tokenizer, dataset):
    try:
        return _create_classification_report_dataframe_on_device(model, tokenizer, dataset, device='/GPU:0')
    except:
        print("Error encountered on GPU, falling back to CPU.")
        return _create_classification_report_dataframe_on_device(model, tokenizer, dataset, device='/CPU:0')

def _create_classification_report_dataframe_on_device(model, tokenizer, dataset, device):
    all_preds = []
    all_labels = []

    with tf.device(device):
        for batch in dataset:
            inputs = batch['input_ids']
            attention_mask = batch['attention_mask']
            batch_labels = batch['labels']

            # Ensure decoder_input_ids are created correctly
            decoder_input_ids = model._shift_right(batch_labels)
            
            outputs = model(input_ids=inputs, attention_mask=attention_mask, decoder_input_ids=decoder_input_ids, labels=batch_labels, training=False)

            # Decode predictions and true labels
            pred_ids = model.generate(input_ids=inputs, attention_mask=attention_mask)
            preds = [set(tokenizer.decode(ids, skip_special_tokens=True).split(', ')) for ids in pred_ids.numpy()]
            labels = [set(tokenizer.decode(ids, skip_special_tokens=True).split(', ')) for ids in batch_labels.numpy()]

            all_preds.extend(preds)
            all_labels.extend(labels)

    # Convert to binary format for multi-label evaluation
    unique_labels = list(set([label for sublist in all_labels for label in sublist]))
    label_to_index = {label: i for i, label in enumerate(unique_labels)}
    
    y_true_bin = np.zeros((len(all_labels), len(unique_labels)))
    y_pred_bin = np.zeros((len(all_preds), len(unique_labels)))
    
    for i, labels in enumerate(all_labels):
        for label in labels:
            if label in label_to_index:
                y_true_bin[i, label_to_index[label]] = 1
    
    for i, preds in enumerate(all_preds):
        for pred in preds:
            if pred in label_to_index:
                y_pred_bin[i, label_to_index[pred]] = 1

    report = classification_report(y_true_bin, y_pred_bin, target_names=unique_labels, zero_division=0, output_dict=True)
    report_df = pd.DataFrame(report).transpose()

    return report_df

# %%
class_report_val = create_classification_report_dataframe(model, tokenizer, val_dataset)

# %% [markdown]
# ## Predictions vs Actuals

# %%
import pandas as pd

def create_evaluation_dataframe(model, tokenizer, dataset):
    try:
        return _create_evaluation_dataframe_on_device(model, tokenizer, dataset, device='/GPU:0')
    except:
        print("Error encountered on GPU, falling back to CPU.")
        return _create_evaluation_dataframe_on_device(model, tokenizer, dataset, device='/CPU:0')

def _create_evaluation_dataframe_on_device(model, tokenizer, dataset, device):
    all_descriptions = []
    all_labels = []
    all_predictions = []

    with tf.device(device):
        for batch in dataset:
            inputs = batch['input_ids']
            attention_mask = batch['attention_mask']
            batch_labels = batch['labels']

            # Ensure decoder_input_ids are created correctly
            decoder_input_ids = model._shift_right(batch_labels)
            
            outputs = model(input_ids=inputs, attention_mask=attention_mask, decoder_input_ids=decoder_input_ids, labels=batch_labels, training=False)

            # Decode input descriptions, predictions, and true labels
            descriptions = [tokenizer.decode(ids, skip_special_tokens=True) for ids in inputs.numpy()]
            pred_ids = model.generate(input_ids=inputs, attention_mask=attention_mask)
            preds = [tokenizer.decode(ids, skip_special_tokens=True) for ids in pred_ids.numpy()]
            labels = [tokenizer.decode(ids, skip_special_tokens=True) for ids in batch_labels.numpy()]

            all_descriptions.extend(descriptions)
            all_labels.extend(labels)
            all_predictions.extend(preds)

    # Create a DataFrame
    df = pd.DataFrame({
        'Description': all_descriptions,
        'Labels': all_labels,
        'Predictions': all_predictions
    })

    return df

# %%
# Use the function to create the DataFrame
evaluation_df = create_evaluation_dataframe(model, tokenizer, val_dataset)

# Display the DataFrame
print(evaluation_df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[78], line 2
#       1 # Use the function to create the DataFrame
# ----> 2 evaluation_df = create_evaluation_dataframe(model, tokenizer, val_dataset)
#       4 # Display the DataFrame
#       5 print(evaluation_df.head())
#
# NameError: name 'create_evaluation_dataframe' is not defined

# %% [markdown]
# # Analyze Results

# %%
# Display the entire sorted DataFrame
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 500)
pd.set_option('display.max_colwidth', None)

pred_test_df = pd.read_csv('/Users/cyrusaghaee/DS 207/Final Project/pred_test_df.csv')

pred_test_df.shape
# Out:
# (500, 2)

# %%
predictions_df.head()
# Out:
#   Description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          brand: ["caili's company"], make: mazda, model: 3, year: ['2010'], fitment: ['direct replacement'], type: ['seal'], manufacturer part number: ['g560-25-744'], part title: ['original equip data g560-25-744'], part brands: ['original equipment data'], subtype: ['drive axle shaft oil slinger'], part types: ['axle shaft'], category: 4.0, item_title: g560-25-744 for 2010 mazda 3 bl transaxle case half shaft oil seal
# 1  brand: ['2006 mini mini cooper stock number: 00017948'], make: mini, model: mini cooper, year: ['2006', '2006'], fitment: ['direct replacement'], manufacturer part number: ['quality,oem,recycled,part,1-year,3-year_ &,lifetime,warranties', 'true', 'alternator'], sku: ['00017948'], category: 0.0, item_title: 2006 mini cooper alternator 96k 957948, cleaned_desc: powered by frooition about us shipping returns contact us payment faq shop categories all categories helpful links add to favorite sellers view feedback contact seller visit seller's ebay shop about seller page 2006 mini cooper alternator 96k 957948 item description 30 day guarantee to ensure you are satisfied with your purchase. please make sure you purchase the correct part the first time, the part must match the year, make and model described below. it must also match the engine size, gear ratio or trim level described in fitment below. make 100% sure it fits before purchase. if in doubt, please email before purchasing. ebay compatibility is not always 100% accurate make sure to confirm with our data below. this alternator fits the following vehicles: 2005-2008 mini cooper 110 amp our inventory notes on exact part: quality,oem,recycled,part,1-year,3-year_ &,lifetime,warranties please make sure part will fit your vehicle before buying! questions ebay message us! this is a proven used alternator. it is being pulled from the vehicle pictured a 2006 mini mini cooper with 96,000 miles. this alternator has been: tested and verified to be in good working order. removed with and will include the pulley. properly boxed for safe shipment to you. no core charge! shipping shipping payment contact us / help shipping shipping • this item will be shipped throughout the continental us via fedex ground. • we do not ship to ak, pr, or hi. • international shipping is not available at this time. • we do not ship to po or apo boxes. your order must have a physical address. orders with only po boxes will not ship until a physical address is provided. • tracking information is sent at time of shipment in most cases
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   brand: ['4 seasons', 'fan motor', 'four seasons'], model: four, year: ['1995', '1996', '1997', '1998', '1999', '2000', '2001'], type: ['motor only', 'oe mount', '4 pole'], manufacturer part number: ['35161'], part title: ['exhaust pipe flange gasket walker 35161', 'exhaust header-base, gas, natural 35161 fits 77-78 pontiac firebird 6.6l-v8', 'exhaust tail pipe tip magnaflow ny 35161', 'carquest/fel-pro 35161 gaskets and sealing systems - engine water pump gasket', 'engine cooling fan motor uni-select 35161 fits 95-01 jeep cherokee 4.0l-l6', 'auto plus/four seasons 35161 - a/c condenser fan motor', 'imco 35161', 'drive axle shaft assembly-axle kit usa standard differential 35161', 'engine cooling fan motor cooling depot 35161', 'exhaust tail pipe tip magnaflow ca 35161', 'engine cooling fan motor parts master 35161 fits 95-01 jeep cherokee 4.0l-l6', 'advance 35161 engine cooling fan motor', 'power steering pump seal kit carquest 35161','murray 35161 engine cooling fan motor', 'engine cooling fan motor carquest 35161', 'exhaust tail pipe tip magnaflow 49 state 35161', 'usa standard gear 35161 service kits - cv axle shaft kit', "engine cooling fan motor o'reilly 35161 fits 95-01 jeep cherokee", 'engine cooling fan motor factory air 35161 fits 95-01 jeep cherokee 4.0l-l6', 'coil spring suplex 35161',
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              brand: ['4 seasons', 'four seasons'], make: hyundai kia, model: sonata optima, year: ['2013', '2011', '2012', '2014', '2013', '2011', '2012', '2014', '2011', '2012', '2013', '2014'], oem part number: ['bp37m5'], product name: ['auxiliary fan assembly'], manufacturer part number: ['radiator fan assembly. -- usa built', 'bp37m5'], sku: ['400:bp37m5'], category: 1.0, item_title: auxiliary fan assembly for 11-14 hyundai kia sonata optima 24l 4 cyl gas bp37m5
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    brand: ['4 seasons', 'four seasons'], type: ['a/c clutch control relay harness connector'], oem part number: ['89051437'], manufacturer part number: ['37220'], sku: ['fs:37220'], part title: ['power steering pressure line hose assembly gates 37220', 'icp/cpi 37220', 'disc brake rotor set-vented sport cross-drilled (pair) brembo 37220', 'auto extra 37220', 'advance 37220 shock absorber', 'a/c clutch control relay harness connector cooling depot 37220', 'auto plus/monroe/expert series 37220 - suspension shock absorber, front', 'federated 37220', 'tail light cover-taillight cover lund 37220', 'a/c clutch control relay harness connector parts master 37220', 'a/c clutch control relay harness connector factory air 37220', "o'reilly 37220 shock absorber", 'auto plus/four seasons 37220 - a/c compressor clutch connector', 'trumark 37220', 'power steering pressure line hose assembly-pressure line assembly carquest 37220', 'hvac blower relay harness connector-engine cooling fan motor relay connector', 'hvac harness connector murray 37220','suspension shock absorber-oespectrum light truck shock absorber canadian tire', 'carquest/monroe 37220 shocks and struts - suspension shock absorber, front', 'power steering pressure line hose assembly-pressure line assembly advance 37220', 'carquest power steering 37220 - power steering pressure hose', 'pb/monroe 37220 shocks and struts - suspension shock absorber, front','suspension shock absorber-oespectrum light truck shock absorber advance 37220', 'visteon 37220', 'auto plus/monroe 372
#
#   Labels                                                     Predictions
# 0                                                      mazda            mazda
# 1                                                       mini             mini
# 2                                                       jeep             jeep
# 3                                               kia, hyundai          hyundai
# 4  chevrolet, buick, pontiac, cadillac, chrysler, oldsmobile  dodge, chrysler

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.metrics import precision_score, recall_score, accuracy_score, fbeta_score, classification_report

# Function to evaluate the model and return incorrect predictions
def evaluate_model_and_find_incorrect_chevrolet(model, tokenizer, dataset):
    all_descriptions = []
    all_labels = []
    all_predictions = []
    incorrect_chevrolet_cases = []

    with tf.device('/CPU:0'):
        for batch in dataset:
            inputs = batch['input_ids']
            attention_mask = batch['attention_mask']
            batch_labels = batch['labels']

            # Ensure decoder_input_ids are created correctly
            decoder_input_ids = model._shift_right(batch_labels)
            
            outputs = model(input_ids=inputs, attention_mask=attention_mask, decoder_input_ids=decoder_input_ids, labels=batch_labels, training=False)
            loss = outputs.loss

            # Decode input descriptions, predictions, and true labels
            descriptions = [tokenizer.decode(ids, skip_special_tokens=True) for ids in inputs.numpy()]
            pred_ids = model.generate(input_ids=inputs, attention_mask=attention_mask)
            preds = [set(tokenizer.decode(ids, skip_special_tokens=True).split(', ')) for ids in pred_ids.numpy()]
            labels = [set(tokenizer.decode(ids, skip_special_tokens=True).split(', ')) for ids in batch_labels.numpy()]

            all_descriptions.extend(descriptions)
            all_labels.extend(labels)
            all_predictions.extend(preds)

            # Identify incorrect predictions for 'chevrolet'
            for desc, label, pred in zip(descriptions, labels, preds):
                if ('chevrolet' in label and 'chevrolet' not in pred) or ('chevrolet' in pred and 'chevrolet' not in label):
                    incorrect_chevrolet_cases.append((desc, label, pred))

    # Create a DataFrame with all predictions
    all_results_df = pd.DataFrame({
        'Description': all_descriptions,
        'Labels': all_labels,
        'Predictions': all_predictions
    })

    # Create a DataFrame for incorrect 'chevrolet' predictions
    incorrect_chevrolet_df = pd.DataFrame(incorrect_chevrolet_cases, columns=['Description', 'Labels', 'Predictions'])

    return all_results_df, incorrect_chevrolet_df

# Assuming test_dataset is defined similarly to train_dataset and val_dataset
test_dataset = tf.data.Dataset.from_tensor_slices((
    {'input_ids': test_encodings['input_ids'], 'attention_mask': test_encodings['attention_mask'], 'labels': test_labels['input_ids']}
)).batch(8)

# Evaluate the model and find incorrect predictions
all_results_df, incorrect_chevrolet_df = evaluate_model_and_find_incorrect_chevrolet(model2, tokenizer2, test_dataset)

# Display the DataFrame with incorrect predictions for 'chevrolet'
print(incorrect_chevrolet_df.head())
# Out:
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:837: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length.  recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
#   Description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           \
# 0  brand: ['4 seasons', 'four seasons'], type: ['a/c clutch control relay harness connector'], oem part number: ['89051437'], manufacturer part number: ['37220'], sku: ['fs:37220'], part title: ['power steering pressure line hose assembly gates 37220', 'icp/cpi 37220', 'disc brake rotor set-vented sport cross-drilled (pair) brembo 37220', 'auto extra 37220', 'advance 37220 shock absorber', 'a/c clutch control relay harness connector cooling depot 37220', 'auto plus/monroe/expert series 37220 - ...
# 1  brand: ['acdelco gm original equipment'], type: ['spark plug wire set'], oem part number: ['12192355'], manufacturer part number: ['706x'], sku: ['400:706x'], part title: ['spark plug wire set acdelco mexico 706x', 'advance 706x spark plug wire set','spark plug wire set acdelco 706x', 'acdelco gm oe/gm genuine parts 706x - spark plug wire set', 'auto plus/acdelco gm original equip 706x - spark plug wire set','spark plug wire set-performa max prenco 706x','spark plug wire set-vin: k, eng code...
# 2                                                                                                                                                                                                                                                                                                                brand: ['advanceignition'], make: gmc, model: envoy, year: ['2003', '2004'], manufacturer part number: ['uce314'], category: 3.0, item_title: 8pc ignition coil uce314 for gmc envoy 53l v8 2003 2004
# 3  brand: ['anchor'], type: ['engine mount'], manufacturer part number: ['3365'], sku: ['anh:3365'], part title: ['mission trading company 3365 - engine coolant reservoir', 'ap exhaust 3365', 'radpro 3365', 'c & w industries 3365', 'carquest/anchor 3365 cylinder block components - engine mount, right','suspension lift kit-wt, 4wd super lift 3365', 'radiator-1 row plastic tank aluminum core csf 3365 fits 2007 acura tl', 'du-so brakes 3365', 'drive axle shaft universal joint sidem 3365','spark pl...
# 4                                                                                                                                                                                                                    brand: ['apf'], make: gmc, model: sonoma, year: ['2000', '1991'], fitment: ['direct replacement'], oem part number: ['07844401'], manufacturer part number: ['07844401'], sku: ['51157'], category: 4.0, item_title: rear driveshaft for 1991-93 gmc sonoma 43l rwd manual 1100in wheelbase steel
#
#   Labels                                                       Predictions
# 0  {chevrolet, buick, pontiac, cadillac, chrysler, oldsmobile}                       {dodge, chrysler}
# 1                                         {chevrolet, pontiac}  {buick, cadil, isuzu, gmc, oldsmobile}
# 2                        {chevrolet, workhorse, gmc, cadillac}                                   {gmc}
# 3                                        {chevrolet, cadillac}                                {nissan}
# 4                                             {chevrolet, gmc}                                   {gmc}

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.metrics import precision_score, recall_score, accuracy_score, fbeta_score, classification_report

# Function to evaluate the model and return predictions
def evaluate_model_with_predictions(model, tokenizer, dataset):
    all_descriptions = []
    all_labels = []
    all_predictions = []

    with tf.device('/CPU:0'):
        for batch in dataset:
            inputs = batch['input_ids']
            attention_mask = batch['attention_mask']
            batch_labels = batch['labels']

            # Ensure decoder_input_ids are created correctly
            decoder_input_ids = model._shift_right(batch_labels)
            
            # Generate predictions
            pred_ids = model.generate(input_ids=inputs, attention_mask=attention_mask)
            preds = [set(tokenizer.decode(ids, skip_special_tokens=True).split(', ')) for ids in pred_ids.numpy()]
            labels = [set(tokenizer.decode(ids, skip_special_tokens=True).split(', ')) for ids in batch_labels.numpy()]
            descriptions = [tokenizer.decode(ids, skip_special_tokens=True) for ids in inputs.numpy()]

            all_descriptions.extend(descriptions)
            all_labels.extend(labels)
            all_predictions.extend(preds)

    # Create a DataFrame with the results
    df = pd.DataFrame({
        'Description': all_descriptions,
        'Labels': all_labels,
        'Predictions': all_predictions
    })

    return df

# Function to calculate metrics and create DataFrames
def calculate_metrics_and_create_dataframes(df):
    # Add the has_desc column
    df['has_desc'] = df['Description'].apply(lambda x: 1 if 'cleaned_desc:' in x else 0)

    # Separate DataFrames based on has_desc
    df_has_desc_1 = df[df['has_desc'] == 1]
    df_has_desc_0 = df[df['has_desc'] == 0]

    # Define a function to calculate individual label metrics
    def calculate_label_metrics(df):
        all_labels = list(set([label for labels in df['Labels'] for label in labels]))
        label_metrics = []

        for label in all_labels:
            y_true = [1 if label in labels else 0 for labels in df['Labels']]
            y_pred = [1 if label in preds else 0 for preds in df['Predictions']]

            precision = precision_score(y_true, y_pred, zero_division=np.nan)
            recall = recall_score(y_true, y_pred, zero_division=np.nan)
            accuracy = accuracy_score(y_true, y_pred)

            label_metrics.append({
                'Label': label,
                'Precision': precision,
                'Recall': recall,
                'Accuracy': accuracy
            })

        return pd.DataFrame(label_metrics)

    # Calculate individual label metrics for both DataFrames
    label_metrics_df_1 = calculate_label_metrics(df_has_desc_1)
    label_metrics_df_0 = calculate_label_metrics(df_has_desc_0)

    # Calculate overall weighted metrics
    y_true_1 = np.array([[1 if label in labels else 0 for label in label_metrics_df_1['Label']] for labels in df_has_desc_1['Labels']])
    y_pred_1 = np.array([[1 if label in preds else 0 for label in label_metrics_df_1['Label']] for preds in df_has_desc_1['Predictions']])
    
    y_true_0 = np.array([[1 if label in labels else 0 for label in label_metrics_df_0['Label']] for labels in df_has_desc_0['Labels']])
    y_pred_0 = np.array([[1 if label in preds else 0 for label in label_metrics_df_0['Label']] for preds in df_has_desc_0['Predictions']])
    
    overall_metrics_1 = {
        'Precision': precision_score(y_true_1, y_pred_1, average='weighted', zero_division=np.nan),
        'Recall': recall_score(y_true_1, y_pred_1, average='weighted', zero_division=np.nan),
        'Accuracy': accuracy_score(y_true_1, y_pred_1)
    }

    overall_metrics_0 = {
        'Precision': precision_score(y_true_0, y_pred_0, average='weighted', zero_division=np.nan),
        'Recall': recall_score(y_true_0, y_pred_0, average='weighted', zero_division=np.nan),
        'Accuracy': accuracy_score(y_true_0, y_pred_0)
    }

    return label_metrics_df_1, label_metrics_df_0, overall_metrics_1, overall_metrics_0

# Assuming test_dataset is defined similarly to train_dataset and val_dataset
test_dataset = tf.data.Dataset.from_tensor_slices((
    {'input_ids': test_encodings['input_ids'], 'attention_mask': test_encodings['attention_mask'], 'labels': test_labels['input_ids']}
)).batch(16)

# Generate predictions on the test set
predictions_df = evaluate_model_with_predictions(model5, tokenizer5, test_dataset)

# Calculate metrics and create DataFrames
label_metrics_df_1, label_metrics_df_0, overall_metrics_1, overall_metrics_0 = calculate_metrics_and_create_dataframes(predictions_df)

# %%
# Display the results


print("\nOverall metrics for has_desc = 1:")
print(overall_metrics_1)


print("\nOverall metrics for has_desc = 0:")
print(overall_metrics_0)
# Out:
# Overall metrics for has_desc = 1:
# {'Precision': 0.9530465078593421, 'Recall': 0.8267716535433071, 'Accuracy': 0.7816091954022989}
#
# Overall metrics for has_desc = 0:
# {'Precision': 0.7652799476382725, 'Recall': 0.554016620498615, 'Accuracy': 0.6416464891041163}

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.metrics import precision_score, recall_score, accuracy_score, fbeta_score, classification_report

# Function to evaluate the model and return predictions
def evaluate_model_with_predictions(model, tokenizer, dataset):
    all_descriptions = []
    all_labels = []
    all_predictions = []

    with tf.device('/CPU:0'):
        for batch in dataset:
            inputs = batch['input_ids']
            attention_mask = batch['attention_mask']
            batch_labels = batch['labels']

            # Ensure decoder_input_ids are created correctly
            decoder_input_ids = model._shift_right(batch_labels)
            
            # Generate predictions
            pred_ids = model.generate(input_ids=inputs, attention_mask=attention_mask)
            preds = [set(tokenizer.decode(ids, skip_special_tokens=True).split(', ')) for ids in pred_ids.numpy()]
            labels = [set(tokenizer.decode(ids, skip_special_tokens=True).split(', ')) for ids in batch_labels.numpy()]
            descriptions = [tokenizer.decode(ids, skip_special_tokens=True) for ids in inputs.numpy()]

            all_descriptions.extend(descriptions)
            all_labels.extend(labels)
            all_predictions.extend(preds)

    # Create a DataFrame with the results
    df = pd.DataFrame({
        'Description': all_descriptions,
        'Labels': all_labels,
        'Predictions': all_predictions
    })

    return df

# Function to calculate metrics and create DataFrames
def calculate_metrics_and_create_dataframes(df):
    # Add the has_desc column
    df['has_desc'] = df['Description'].apply(lambda x: 1 if 'make:' in x else 0)

    # Separate DataFrames based on has_desc
    df_has_desc_1 = df[df['has_desc'] == 1]
    df_has_desc_0 = df[df['has_desc'] == 0]

    # Define a function to calculate individual label metrics
    def calculate_label_metrics(df):
        all_labels = list(set([label for labels in df['Labels'] for label in labels]))
        label_metrics = []

        for label in all_labels:
            y_true = [1 if label in labels else 0 for labels in df['Labels']]
            y_pred = [1 if label in preds else 0 for preds in df['Predictions']]

            precision = precision_score(y_true, y_pred, zero_division=np.nan)
            recall = recall_score(y_true, y_pred, zero_division=np.nan)
            accuracy = accuracy_score(y_true, y_pred)

            label_metrics.append({
                'Label': label,
                'Precision': precision,
                'Recall': recall,
                'Accuracy': accuracy
            })

        return pd.DataFrame(label_metrics)

    # Calculate individual label metrics for both DataFrames
    label_metrics_df_1 = calculate_label_metrics(df_has_desc_1)
    label_metrics_df_0 = calculate_label_metrics(df_has_desc_0)

    # Calculate overall weighted metrics
    y_true_1 = np.array([[1 if label in labels else 0 for label in label_metrics_df_1['Label']] for labels in df_has_desc_1['Labels']])
    y_pred_1 = np.array([[1 if label in preds else 0 for label in label_metrics_df_1['Label']] for preds in df_has_desc_1['Predictions']])
    
    y_true_0 = np.array([[1 if label in labels else 0 for label in label_metrics_df_0['Label']] for labels in df_has_desc_0['Labels']])
    y_pred_0 = np.array([[1 if label in preds else 0 for label in label_metrics_df_0['Label']] for preds in df_has_desc_0['Predictions']])
    
    overall_metrics_1 = {
        'Precision': precision_score(y_true_1, y_pred_1, average='weighted', zero_division=np.nan),
        'Recall': recall_score(y_true_1, y_pred_1, average='weighted', zero_division=np.nan),
        'Accuracy': accuracy_score(y_true_1, y_pred_1)
    }

    overall_metrics_0 = {
        'Precision': precision_score(y_true_0, y_pred_0, average='weighted', zero_division=np.nan),
        'Recall': recall_score(y_true_0, y_pred_0, average='weighted', zero_division=np.nan),
        'Accuracy': accuracy_score(y_true_0, y_pred_0)
    }

    return label_metrics_df_1, label_metrics_df_0, overall_metrics_1, overall_metrics_0

# Assuming test_dataset is defined similarly to train_dataset and val_dataset
test_dataset = tf.data.Dataset.from_tensor_slices((
    {'input_ids': test_encodings['input_ids'], 'attention_mask': test_encodings['attention_mask'], 'labels': test_labels['input_ids']}
)).batch(16)

# Generate predictions on the test set
predictions_df = evaluate_model_with_predictions(model5, tokenizer5, test_dataset)

# Calculate metrics and create DataFrames
label_metrics_df_1, label_metrics_df_0, overall_metrics_1, overall_metrics_0 = calculate_metrics_and_create_dataframes(predictions_df)
# Out:
# /Users/cyrusaghaee/myenv/lib/python3.11/site-packages/transformers/generation/tf_utils.py:837: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length.  recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(

# %%
predictions_df.head(500)
# Out:
#     Description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           \
# 0                                                                                         brand: ["caili's company"], make: mazda, model: 3, year: ['2010'], fitment: ['direct replacement'], type: ['seal'], manufacturer part number: ['g560-25-744'], part title: ['original equip data g560-25-744'], part brands: ['original equipment data'], subtype: ['drive axle shaft oil slinger'], part types: ['axle shaft'], category: 4.0, item_title: g560-25-744 for 2010 mazda 3 bl transaxle case half shaft oil seal
# 1    brand: ['2006 mini mini cooper stock number: 00017948'], make: mini, model: mini cooper, year: ['2006', '2006'], fitment: ['direct replacement'], manufacturer part number: ['quality,oem,recycled,part,1-year,3-year_ &,lifetime,warranties', 'true', 'alternator'], sku: ['00017948'], category: 0.0, item_title: 2006 mini cooper alternator 96k 957948, cleaned_desc: powered by frooition about us shipping returns contact us payment faq shop categories all categories helpful links add to favorite sel...
# 2    brand: ['4 seasons', 'fan motor', 'four seasons'], model: four, year: ['1995', '1996', '1997', '1998', '1999', '2000', '2001'], type: ['motor only', 'oe mount', '4 pole'], manufacturer part number: ['35161'], part title: ['exhaust pipe flange gasket walker 35161', 'exhaust header-base, gas, natural 35161 fits 77-78 pontiac firebird 6.6l-v8', 'exhaust tail pipe tip magnaflow ny 35161', 'carquest/fel-pro 35161 gaskets and sealing systems - engine water pump gasket', 'engine cooling fan motor u...
# 3                                             brand: ['4 seasons', 'four seasons'], make: hyundai kia, model: sonata optima, year: ['2013', '2011', '2012', '2014', '2013', '2011', '2012', '2014', '2011', '2012', '2013', '2014'], oem part number: ['bp37m5'], product name: ['auxiliary fan assembly'], manufacturer part number: ['radiator fan assembly. -- usa built', 'bp37m5'], sku: ['400:bp37m5'], category: 1.0, item_title: auxiliary fan assembly for 11-14 hyundai kia sonata optima 24l 4 cyl gas bp37m5
# 4    brand: ['4 seasons', 'four seasons'], type: ['a/c clutch control relay harness connector'], oem part number: ['89051437'], manufacturer part number: ['37220'], sku: ['fs:37220'], part title: ['power steering pressure line hose assembly gates 37220', 'icp/cpi 37220', 'disc brake rotor set-vented sport cross-drilled (pair) brembo 37220', 'auto extra 37220', 'advance 37220 shock absorber', 'a/c clutch control relay harness connector cooling depot 37220', 'auto plus/monroe/expert series 37220 - ...
# 5    brand: ['4 seasons', 'four seasons'], type: ['engine coolant outlet flange'], oem part number: ['06a121132'], manufacturer part number: ['85336'], sku: ['fs:85336'], part title: ["radiator coolant hose flange-coolant flange o'reilly 85336", 'radiator coolant hose flange-coolant flange factory air 85336', 'trumark 85336', 'engine coolant outlet flange-coolant flange carquest 85336', 'engine coolant outlet flange-coolant flange advance 85336', 'engine coolant outlet flange-coolant flange 4 sea...
# 6    brand: ['4 seasons', 'four seasons'], type: ['engine coolant thermostat/water outlet assembly'], oem part number: ['4893926ag'], manufacturer part number: ['86269'], sku: ['fs:86269'], part title: ['engine coolant thermostat / water outlet assembly 4 seasons 86269', 'engine coolant thermostat / water outlet assembly uni-select 86269','spark plug wire set-vin: s, 2bbl mighty 86269', 'auto extra 86269','spark plug wire set-vin: h prenco 86269', "engine coolant thermostat / water outlet assembl...
# 7                                                                                                                                                                    brand: ['ac delco genuine gm'], make: gmc v3500, model: v3500, year: ['1989', '1990', '1991', '1989', '1990', '1991', '1989', '1990', '1991'], fitment: ['genuine gm'], type: ['distributor cap'], oem part number: ['65gvns'], sku: ['400:65gvns'], category: 3.0, item_title: ac delco genuine gm distributor cap fits gmc v3500 1989-1991 65gvns
# 8                                                                                                                         brand: ['ac delco gold (professional)'], make: gmc r2500 suburban, model: r2500 suburban, year: ['1989', '1990', '1991', '1989', '1990', '1991', '1989', '1990', '1991'], fitment: ['gold (professional)'], type: ['radiator hose'], oem part number: ['28ydth'], sku: ['400:28ydth'], category: 1.0, item_title: upper ac delco radiator hose fits gmc r2500 suburban 1989-1991 74l v8 28ydth
# 9            brand: ['ac delco professional'], make: toyota 4runner, model: 4runner, year: ['2003', '2004', '2005', '2006', '2007', '2008', '2009', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2003', '2004', '2005', '2006', '2007', '2008', '2009'], fitment: ['professional -- new; interference engine application'], type: ['timing belt kit'], oem part number: ['42bbnc'], sku: ['400:42bbnc'], category: 2.0, item_title: ac delco timing belt kit fits toyota 4runner 2003-2009 47l v8 gas 42bbnc
# 10                                                                                    brand: ['ac delco'], make: bmw, model: 530i, year: ['2017', '1994', '1995', '2002', '2003', '2004', '2005', '2006', '2007'], oem part number: ['35439xy'], product name: ['variable timing solenoid connector', 'engine variable valve timing (vvt) solenoid connector'], manufacturer part number: ['35439xy'], sku: ['400:35439xy'], category: 2.0, item_title: for bmw 530i variable timing solenoid connector ac delco 35439xy
# 11                                                                                                                                                                                                                                                                               brand: ['ac delco'], make: jeep, year: ['1985', '1986'], type: ['radiator hose'], oem part number: ['3vsf52'], sku: ['400:3vsf52'], category: 1.0, item_title: upper radiator hose ac delco 3vsf52 for jeep cherokee comanche 1985 1986
# 12                                                                                                                                                                                                                             brand: ['ac delco'], model: s112, year: ['1957', '1957', '1957'], fitment: ['international s112 ignition coil'], oem part number: ['h716yn'], product name: ['ignition coil'], sku: ['400:h716yn'], category: 3.0, item_title: ignition coil for 1957 international s112 39l 6 cyl h716yn
# 13                                                                                                                                                brand: ['ac delco'], year: ['1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000'], oem part number: ['65841kx'], product name: ['auto trans output shaft speed sensor connector'], manufacturer part number: ['65841kx'], sku: ['400:65841kx'], category: 4.0, item_title: for e150 econoline auto trans output shaft speed sensor connector 65841kx
# 14   brand: ['accel'], make: chevrolet, model: impala, year: ['1974', '1973', '1972', '1971', '1970', '1969', '1968', '1967', '1966', '1965', '1964', '1963', '1962', '1958', '1959', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974'], fitment: ['direct replacement'], type: ['distributor cap and rotor kit'], manufacturer part number: ['sx-qzmg 1974 1973 1972 1971 1970 1969'], category: 3.0, item_title: accel distributor cap rotor ...
# 15                                                                                                                brand: ['accel'], make: mazda, model: b2200, year: ['1993', '1992', '1991', '1990', '1989', '1988', '1987', '1987', '1988', '1989', '1990', '1991', '1992', '1993'], fitment: ['direct replacement'], type: ['ignition coil'], manufacturer part number: ['sx-mwp3 1993 1992 1991 1990 1989 1988'], category: 3.0, item_title: accel ignition coil for 1987-1993 mazda b2200 - wire boot spark plug xq
# 16                                                                             brand: ['accel'], make: plymouth, model: road runner, year: ['1975', '1974', '1973', '1972', '1971', '1970', '1969', '1968', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975'], fitment: ['direct replacement'], type: ['spark plug wire set'], manufacturer part number: ['sx-54xm 1975 1974 1973 1972 1971 1970'], category: 3.0, item_title: accel spark plug wire set for 1968-1975 plymouth road runner 63l 66l 72l fo
# 17                                                                                                                 brand: ['accel'], model: 6, type: ['direct ignition coil kit'], manufacturer part number: ['140061b-6'], sku: ['502:140061b-6'], part title: ['ignition coil set-supercoil direct accel 140061b-6'], part brands: ['accel'], subtype: ['direct ignition coil'], part types: ['ignition coil'], category: 3.0, item_title: direct ignition coil kit-supercoil direct ignition coil set accel 140061b-6
# 18   brand: ['acdelco gm original equipment'], type: ['spark plug wire set'], oem part number: ['12192355'], manufacturer part number: ['706x'], sku: ['400:706x'], part title: ['spark plug wire set acdelco mexico 706x', 'advance 706x spark plug wire set','spark plug wire set acdelco 706x', 'acdelco gm oe/gm genuine parts 706x - spark plug wire set', 'auto plus/acdelco gm original equip 706x - spark plug wire set','spark plug wire set-performa max prenco 706x','spark plug wire set-vin: k, eng code...
# 19   brand: ['acdelco professional', 'acdelco'], make: toyota, model: camry, year: ['1992'], type: ['hvac heater hose'], oem part number: ['16070611'], manufacturer part number: ['16099m'], sku: ['acd:16099m'], part title: ['hvac heater hose-molded acdelco 16099m fits 92-96 toyota camry 2.2l-l4', 'auto plus/acdelco professional/gold 16099m hoses and pipes - hvac heater hose', 'acdelco professional/gold 16099m hoses and pipes - hvac heater hose', 'hvac heater hose-molded heater hose acdelco 16099m...
# 20   brand: ['acdelco professional', 'acdelco'], type: ['hvac heater hose'], oem part number: ['09128710'], manufacturer part number: ['16330m'], sku: ['501:16330m'], part title: ['auto extra 16330m', 'acdelco professional/gold 16330m hoses and pipes - hvac heater hose', 'hvac heater hose-molded heater hose acdelco 16330m', 'auto plus/acdelco professional/gold 16330m hoses and pipes - hvac heater hose', 'hvac heater hose-molded acdelco 16330m'], part brands: ['acdelco/gold', 'acdelco', 'auto plus...
# 21   brand: ['acdelco'], make: chrysler, year: ['1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987'], type: ['alternator'], manufacturer part number: ['334-2214'], part title: ['auto extra 334-2214 reman', 'advance 334-2214 alternator', 'acdelco professional/gold 3342214 - alternator', 'auto plus/acdelco professional/gold 3342214 - alternator', 'carquest/acdelco professional/gold 3342214 - alternator', 'alt...
# 22   brand: ['acdelco'], model: camaro, year: ['2012', '2013', '2014', '2015'], fitment: ['direct replacement'], type: ['water pumps'], product name: ['engine coolant water pump kit'], manufacturer part number: ['251-728'], part title: ['engine water pump acdelco mexico 251-728', 'engine water pump-water pump kit acdelco 251-728', 'engine water pump kit acdelco 251-728', 'acdelco gm oe/gm genuine parts 251728 - engine water pump', 'engine water pump acdelco pro 251-728', 'auto extra 251-728', 'en...
# 23                   brand: ['acl bearings'], make: chrysler, year: ['1958', '1959', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980'], fitment: ['performance/custom', 'no'], type: ['connecting rod bearings'], oem part number: ['8b527p-20'], manufacturer part number: ['8b527p-20'], category: 2.0, item_title: acl 20mm oversized rod bearing set fits 1958-1980 chrysler prod v8 383400440
# 24   brand: ['acura'], make: acura, model: acura mdx, year: ['2011'], fitment: ['direct replacement'], manufacturer part number: ['does not apply'], sku: ['pp057', 'f6522021-2e2b-4169-84b1-c011758a05cc'], category: 0.0, item_title: enginemotor brain box acura mdx 10 11, cleaned_desc: borges foreign auto parts, inc. dighton, ma business hours (est/edt) mon - fri 8:00am - 5:00pm saturday 9:00am - 2:00pm - closed sundays engine/motor brain box year: 11 model: acura mdx side: type: used category: w c...
# 25   brand: ['acura'], make: acura, model: cl, year: ['2001', '2001', '2002'], vehicle identification number: ['19uya42721a010026'], sku: ['nlk984', '19599282'], category: 0.0, item_title: engine ecm electronic control module lower center dash fits 01-02 cl 19599282, cleaned_desc: hollander welcome to our ebay store! engine ecm electronic control module lower center dash fits 01-02 cl 19599282 description dealer programing may be required please message with any questions prior to ordering donor ...
# 26   brand: ['acura'], make: acura, year: ['2017'], manufacturer part number: ['tlx343435556lkq'], vehicle identification number: ['19uub1f52ha002585'], category: 0.0, item_title: 2017 acura tlx engine computer control module ecu 95k miles oe lkq343435556, cleaned_desc: ****important**** click here to see full part description and important part fitment information. ***important notice regarding responses to messages*** thank you for your interest in our item. due to heavy sales volume and limite...
# 27                                                                                                                                                                                                                                                                                                                 brand: ['advanceignition'], make: gmc, model: envoy, year: ['2003', '2004'], manufacturer part number: ['uce314'], category: 3.0, item_title: 8pc ignition coil uce314 for gmc envoy 53l v8 2003 2004
# 28                                                                                                                                                                                     brand: ['aisin'], make: toyota, model: 4runner, year: ['2003', '2004', '2003', '2004', '2003', '2004'], fitment: ['toyota 4runner oil pump'], oem part number: ['q231mv'], product name: ['oil pump'], sku: ['400:q231mv'], category: 2.0, item_title: oil pump for 2003-2004 toyota 4runner 47l v8 2uz-fe q231mv engine oil pump
# 29                                                                                                                                                                                                                         brand: ['aisin'], manufacturer part number: ['fht-019'], part title: ['locking hub-4wd aisin fht-019 fits 1995 toyota tacoma'], part brands: ['aisin'], subtype: ['locking hub'], part types: ['axle shaft'], category: 4.0, item_title: aisin fht-019 driveline and axles 4wd free wheel hub
# 30                                                                                                      brand: ['aisin'], type: ['engine cooling fan clutch'], oem part number: ['1621050102'], manufacturer part number: ['fct-075'], sku: ['ais:fct-075'], part title: ['engine cooling fan clutch-eng code: 2uz-fe aisin fct-075'], part brands: ['aisin'], subtype: ['engine cooling fan clutch'], part types: ['cooling fan, clutch and motor'], category: 1.0, item_title: engine cooling fan clutch aisin fct-075
# 31                                                                                                                                  brand: ['aisin'], type: ['engine water pump'], oem part number: ['2101031u25'], manufacturer part number: ['wpn-070'], sku: ['ais:wpn-070'], part title: ['engine water pump-eng code: vq30de aisin wpn-070'], part brands: ['aisin'], subtype: ['engine water pump'], part types: ['water pump and related components'], category: 1.0, item_title: engine water pump aisin wpn-070
# 32   brand: ['alloyworks'], make: gmc, model: s10, year: ['1988', '1989', '1990', '1991', '1992', '1993', '1994'], fitment: ['direct replacement', 'for 1988-1994 chevrolet s10 blazer 4.3l', 'for 1988-1993 chevrolet s10 4.3l', 'for 1992-1994 gmc jimmy 4.3l', 'for 1988-1990 gmc s15 4.3l', 'for 1988-1991 gmc s15 jimmy 4.3l', 'for 1991-1993 gmc sonoma 4.3l', 'for 1991-1994 oldsmobile bravada 4.3l'], type: ['radiator'], manufacturer part number: ['yes'], category: 1.0, item_title: 4-row aluminum radia...
# 33   brand: ['alzare'], make: ford, model: escape, year: ['2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012'], fitment: ['direct replacement'], type: ['coolant overflow tanks'], product name: ['engine coolant recovery tank'], manufacturer part number: ['fo3014107'], part title: ['engine coolant reservoir lkq corp fo3014107 fits 2001 ford escape'], part brands: ['lkq corp'], subtype: ['engine coolant reservoir'], part types: ['radiators, coolers and rela...
# 34                                                                                                                                                                                                      brand: ['am autoparts'], model: elantra, fitment: ['direct replacement'], type: ['cv axle shaft set'], oem part number: ['495003x100, 495013x100, 495013y100'], manufacturer part number: ['am-1986035625'], category: 4.0, item_title: front cv axle shaft assembly pair set 2pc for elantra sedan gt 4 door at
# 35   brand: ['amoto'], make: acura, model: el, year: ['2001', '2002', '2003', '2004', '2005'], type: ['ignition coil', 'blade'], oem part number: ['30520pvja01'], manufacturer part number: ['30520-pvf-a01'], part title: ['direct ignition coil prenco 30520-pvf-a01', 'original equip data 30520-pvf-a01'], part brands: ['original equipment data', 'prenco'], subtype: ['direct ignition coil'], part types: ['ignition coil'], category: 3.0, item_title: uf400 4x ignition coil 4 spark plug for 17l 02-04 ac...
# 36                                                                      brand: ['anchor'], make: chevrolet, model: malibu, year: ['2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005', '2004', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012'], fitment: ['direct replacement'], type: ['engine mount'], manufacturer part number: ['sx-1n6e 2012 2011 2010 2009 2008 2007'], category: 2.0, item_title: anchor right engine mount for 2004-2012 chevrolet malibu 35l 36l 39l v6 - ra
# 37   brand: ['anchor'], type: ['engine mount'], manufacturer part number: ['3365'], sku: ['anh:3365'], part title: ['mission trading company 3365 - engine coolant reservoir', 'ap exhaust 3365', 'radpro 3365', 'c & w industries 3365', 'carquest/anchor 3365 cylinder block components - engine mount, right','suspension lift kit-wt, 4wd super lift 3365', 'radiator-1 row plastic tank aluminum core csf 3365 fits 2007 acura tl', 'du-so brakes 3365', 'drive axle shaft universal joint sidem 3365','spark pl...
# 38   brand: ['anchor'], type: ['engine mount'], oem part number: ['a7314'], manufacturer part number: ['9200'], sku: ['am:9200'], part title: ['carquest/champion spark plug 9200 secondary ignition - spark plug', 'advance 9200 spark plug', 'engine mount pep boys 9200', 'rack and pinion seal kit advance 9200', 'auto plus/champion spark plug 9200 secondary ignition - spark plug', 'exhaust heat shield carquest 9200', 'truck bed rail-to-rail tool box deflecta-shield 9200', 'drum brake hardware kit bet...
# 39                                        brand: ['anytek'], make: toyota, model: rav4, year: ['2011', '2012', '2013', '2014', '2015', '2016', '2017'], fitment: ['direct replacement'], manufacturer part number: ['to-8-8833'], part title: ['cv axle shaft-std trans front-left/right autopart trust to-8-8833'], part brands: ['autopart trust'], subtype: ['cv axle shaft'], part types: ['cv components'], category: 4.0, item_title: front left cv axle half for 2013-2017 toyota rav4 exc ev hybrid 2011-2016 tc
# 40                                                                                                                                                                                                  brand: ['apa/uro parts'], make: bmw, year: ['2014', '2015', '2016', '2014', '2015', '2016'], oem part number: ['52169zs'], product name: ['coolant level sensor'], manufacturer part number: ['52169zs'], sku: ['400:52169zs'], category: 1.0, item_title: for 2014-2016 bmw m235i coolant level sensor 52169zs 2015
# 41                                               brand: ['apa/uro parts'], year: ['2009', '2007', '2006', '2008', '2009', '2007', '2006', '2008', '2006', '2007', '2008', '2009'], fitment: ['volkswagen rabbit auxiliary engine cooling fan assembly'], oem part number: ['km538zv'], product name: ['auxiliary engine cooling fan assembly'], manufacturer part number: ['km538zv'], sku: ['400:km538zv'], category: 1.0, item_title: right auxiliary engine cooling fan assembly for 2006-2009 vw rabbit 2007 km538zv
# 42                                                                                                                                                                                         brand: ['apdi'], make: mitsubishi, year: ['2013', '2011', '2012', '2011', '2012', '2013'], oem part number: ['87618bdvx'], product name: ['radiator'], manufacturer part number: ['87618bdvx'], sku: ['400:87618bdvx'], category: 1.0, item_title: for 2011-2013 mitsubishi outlander sport radiator 87618bdvx 2012 20l 4 cyl
# 43                                                                                                                                                                                                                                          brand: ['apf'], make: bmw, model: z3, year: ['1996'], fitment: ['direct replacement'], oem part number: ['33201229235'], manufacturer part number: ['33201229235'], category: 4.0, item_title: cv axle shaft for 1996-98 bmw z3 19l l4 gas rear driver passenger side 2330in
# 44                                                                                                           brand: ['apf'], make: ford, model: fusion, year: ['2000', '2013'], fitment: ['direct replacement'], oem part number: ['dg913b436ba,dg913b436bb,dg913b436bc,dg9z3b436a,tx617'], manufacturer part number: ['dg913b436bc', 'dg913b436ba,dg913b436bb,dg913b436bc,dg9z3b436a,tx617'], sku: ['24187'], category: 4.0, item_title: cv axle shaft for 2013-14 ford fusion turbo fwd manual front right side 2386in
# 45                                                                                                                                                                                                                     brand: ['apf'], make: gmc, model: sonoma, year: ['2000', '1991'], fitment: ['direct replacement'], oem part number: ['07844401'], manufacturer part number: ['07844401'], sku: ['51157'], category: 4.0, item_title: rear driveshaft for 1991-93 gmc sonoma 43l rwd manual 1100in wheelbase steel
# 46                                                                                                                                                                                                         brand: ['apf'], make: hyundai, model: sonata, year: ['2000', '2006'], fitment: ['direct replacement'], oem part number: ['495000a100'], manufacturer part number: ['495000a100'], sku: ['579275'], category: 4.0, item_title: cv axle shaft assembly for 2006-10 hyundai sonata manual front left driver side
# 47                                                                                                                                                                                                                      brand: ['apf'], make: land rover, model: discovery, year: ['1999', '2000', '2001', '2002', '2003', '2004'], fitment: ['direct replacement'], oem part number: ['stc4434'], manufacturer part number: ['stc4434'], category: 1.0, item_title: coolant pump discovery fits 99-04 land rover 569328
# 48                                                                                                  brand: ['apf'], make: saturn, model: sl2, year: ['2000', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002'], fitment: ['direct replacement'], oem part number: ['22135271,22136898,22098757'], manufacturer part number: ['22135271', '22135271,22136898,22098757'], sku: ['121878'], category: 1.0, item_title: radiator and condenser fan assembly for 1994-2002 saturn sl2 single fan shroud
# 49   brand: ['apf'], model: 200, year: ['2000', '2011', '2012', '2013', '2014'], fitment: ['direct replacement'], oem part number: ['68031873aa,68031871aa,68020410aa'], manufacturer part number: ['68031873aa,68031871aa,68020410aa', '68031873aa'], sku: ['2103446'], part title: ['engine cooling fan motor-sport, vin: a, fwd mopar 68031873aa', 'engine cooling fan motor crown 68031873aa'], part brands: ['crown automotive sales co.','mopar'], subtype: ['engine cooling fan|engine cooling fan assembly|en...
# 50   brand: ['apf'], model: corolla, year: ['2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016'], fitment: ['direct replacement'], oem part number: ['281000t050,281000t051,281000t260,2810037050,2810037051'], manufacturer part number: ['281000t050,281000t051,281000t260,2810037050,2810037051', '2810037051'], category: 0.0, item_title: starter motor 16kw fits 09-16 corolla 3234721, cleaned_desc: hollander welcome to our ebay store! starter motor 1.6kw fits 09-16 corolla 3234721 descriptio...
# 51                                                                                                  brand: ['api protune'], make: ford, model: f350, year: ['1994', '1989', '1990', '1991', '1992', '1993', '1995', '1996', '1997', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997'], oem part number: ['22mp64h'], manufacturer part number: ['protune', '22mp64h'], sku: ['400:22mp64h'], category: 4.0, item_title: api 22mp64h automatic transmission filter kit fits 1989-1997 ford f350 rwd
# 52                                                                                                                 brand: ['api'], make: isuzu, year: ['1996', '1997', '1998', '1999', '1996', '1997', '1998', '1999', '1996', '1997', '1998', '1999'], fitment: ['isuzu oasis oil filter'], oem part number: ['nc762dz'], product name: ['oil filter'], manufacturer part number: ['nc762dz'], sku: ['400:nc762dz'], category: 2.0, item_title: oil filter for 1996-1999 isuzu oasis 1997 1998 nc762dz protune extended
# 53   brand: ['api'], make: nissan xterra, model: xterra, year: ['2011', '2012', '2008', '2005', '2006', '2007', '2009', '2010', '2011', '2012', '2008', '2005', '2006', '2007', '2009', '2010', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012'], fitment: ['engine coolant reservoir cap -- standard; 16 lb; mini cap'], type: ['expansion tank cap'], oem part number: ['69bdxj'], manufacturer part number: ['69bdxj'], sku: ['400:69bdxj'], category: 1.0, item_title: api expansion tank cap fits...
# 54                                                                                                                brand: ['api'], make: pontiac, year: ['2007', '2008', '2009', '2010', '2007', '2008', '2009', '2010', '2007', '2008', '2009', '2010'], fitment: ['pontiac g5 engine mount'], oem part number: ['qh914gy'], product name: ['engine mount'], manufacturer part number: ['qh914gy'], sku: ['400:qh914gy'], category: 2.0, item_title: front right engine mount for 2007-2010 pontiac g5 2008 2009 qh914gy
# 55                                                                                                                                                                                                                                                                   brand: ['as-speedfather'], model: ls2, type: ['valve cover'], oem part number: ['mhh005b '], manufacturer part number: ['asf17625ed835r'], category: 2.0, item_title: aluminum cast polished valve covers with coil mounts for gm ls ls1 ls2 ls3 53
# 56   brand: ['audi tt, a3 (3.2l)'], make: audi, model: vw gti, passat, jetta (2.0l), manufacturer part number: ['02e-911-023-lx'], category: 0.0, item_title: 02e-911-023-lx oem starter motor for audi tt a3 32l vw gti passat jetta 20l, cleaned_desc: oem traders international visit our store! visita nuestra tienda!! visitez notre magasin! besuchen sie unseren shop! 02e-911-023-lx oem starter motor for audi tt, a3 3.2l vw gti, passat, jetta 2.0l important item information: this fits: 2008-2009 audi ...
# 57                                                                                                                                                                                                                                                               brand: ['audi'], make: audi, model: a5, year: ['2010'], manufacturer part number: ['a5333826441lkq'], vehicle identification number: ['waujfafh2an021827'], category: 1.0, item_title: 2010 audi a5 coolant overflow bottle oem 100k miles lkq333826441
# 58   brand: ['audi'], make: audi, model: a6, year: ['2012', '2013', '2014', '2015', '2016', '2017'], fitment: ['unknown'], type: ['junction block', 'unknown'], oem part number: ['4g0937517 / 4g0 937 517'], manufacturer part number: ['4g0937517 / 4g0 937 517', 'no'], vehicle identification number: ['no'], category: 0.0, item_title: 2012-2017 audi a6 quattro relay fuse box battery junction block oem, cleaned_desc: donor: 2014 audi a6 quattro prestige sedan donor engine: 3.0l v6 dohc 24v, gasoline d...
# 59   brand: ['audi'], make: audi, model: audi q5, year: ['2011'], fitment: ['direct replacement'], oem part number: ['8t0907468ab'], manufacturer part number: ['8t0907468ab'], sku: ['q135', '10e5ff1f-173c-49c6-8b7f-179bcc5c2e59'], category: 0.0, item_title: 09 10 11 12 audi q5 8t0907468ab interface gateway control module, cleaned_desc: black gold import auto parts ltd black gold import auto parts ltd nisku, ab business hours (mst/mdt) mon - fri 8:00am - 5:00pm closed sat & sun this chassis brain ...
# 60   brand: ['audi'], make: audi, model: q5, year: ['2018', '2019', '2020', '2021', '2022', '2023'], oem part number: ['4m0907247 / 4m0907 247 / 4m0 907 247'], manufacturer part number: ['80a907247 / 80a907 247 / 80a 907 247'], sku: ['1359'], category: 0.0, item_title: 2018 - 2023 audi q5 rear right door keyless entry antenna module oem 80a907247, cleaned_desc: ebay listing template example :: car-part.com a plus auto, llc nicholasville, ky business hours (eastern) mon - fri 8am - 5pm • sat & sun...
# 61   brand: ['audi'], make: audi, year: ['2008', '2009'], fitment: ['direct replacement'], type: ['engine control unit (ecu)'], oem part number: ['4e1910560d'], manufacturer part number: ['4e1-910-560-d'], category: 0.0, item_title: audi a8 quattro ecm ecu pcm engine control module 42l oem 2008 2009, cleaned_desc: audi a8 quattro ecm ecu pcm engine control module 4.2l oem 2008 2009 -the compatibility chart is a reference, always check the manufacture, supersede or interchange part numbers, especi...
# 62                                                                                                                             brand: ['autopart premium'], make: lexus, year: ['2005', '2004', '2006', '2005', '2004', '2006', '2004', '2005', '2006'], fitment: ['lexus es330 ignition coil'], oem part number: ['zc836np'], product name: ['ignition coil'], manufacturer part number: ['zc836np'], sku: ['400:zc836np'], category: 3.0, item_title: ignition coil for 2004-2006 lexus es330 base 33l v6 2005 zc836np
# 63                                                                                                                                                                                 brand: ['autopart premium'], make: volkswagen, model: touareg, year: ['2004', '2005', '2006', '2004', '2005', '2006'], oem part number: ['75zc35j'], manufacturer part number: ['75zc35j', 'ignition coil'], sku: ['400:75zc35j'], category: 3.0, item_title: autopart premium 75zc35j ignition coil fits 2004-2006 vw touareg 42l v8
# 64                                                    brand: ['autopart premium'], year: ['1970', '1971', '1972', '1973', '1974', '1970', '1971', '1972', '1973', '1974', '1970', '1971', '1972', '1973', '1974'], fitment: ['american motors hornet spark plug wire set'], oem part number: ['sk853tw'], product name: ['spark plug wire set'], manufacturer part number: ['sk853tw'], sku: ['400:sk853tw'], category: 3.0, item_title: spark plug wire set for 1970-1974 american motors hornet 1971 1972 1973 sk853tw
# 65                                                                                                                                                                       brand: ['baochi cars'], make: nissan, model: fit, year: ['1998', '1999', '2000', '2001', '1998', '1999', '2000', '2001'], fitment: ['direct replacement'], type: ['solenoid valve'], manufacturer part number: ['14956-1p101, 149561p101'], category: 3.0, item_title: new solenoid valve fit for nissan altima 1998-2001 149561p101 149561p100
# 66                                                                                                                                                                                                    brand: ['bavarian motor works (bmw)'], make: bmw, model: bmw 535i, year: ['2011', '2011'], fitment: ['direct replacement'], manufacturer part number: ['does not apply'], sku: ['170035', 'ae916d8a-e06c-46f4-8a58-c0e37936263d'], category: 4.0, item_title: 11 bmw 535i carrier assembly 2011 bmw 535i oem atrwd
# 67                                                                                                                                                                                                      brand: ['bavarian motor works (bmw)'], make: bmw, model: m850i, year: ['2019', '2019'], fitment: ['direct replacement'], manufacturer part number: ['does not apply'], sku: ['u95792', '3d9363d4-7949-4f98-b470-81d446ab8fcc'], category: 4.0, item_title: 2019 bmw m850i oem 44l 8 speed automatic transmission
# 68   brand: ['bbb industries'], make: subaru, model: impreza, year: ['1993', '1994', '1995', '1996', '1997'], type: ['alternator'], oem part number: ['28010220'], manufacturer part number: ['13479'], sku: ['bbb:13479'], part title: ['ultima 13479 reman', 'better brake 13479','mpa 13479 alternator / generator and related components - alternator', 'alternator vision oe 13479 reman fits 93-97 subaru impreza 1.8l-h4', 'auto plus/pro select 13479 reman - alternator', 'uni-select 13479 reman', 'alterna...
# 69   brand: ['bbb industries'], type: ['alternator'], manufacturer part number: ['7801-7'], sku: ['615:7801-7'], part title: ['alternator bbb industries 7801-7 reman', 'genco 7801-7', 'con-rel auto electric 78017 - alternator', 'alternator rotex 7801-7 reman', 'alternator uni-select 7801-7 reman','maxpower rebuilders 7801-7 reman','suncoast 7801-7', 'ap auto electric 78017 - alternator', 'ltd parts 7801-7', 'visteon 7801-7', 'alternator proamp 7801-7 reman', 'alternator-vin: n, gas, fi, natural m...
# 70   brand: ['bbb industries'], type: ['alternator'], oem part number: ['373003c250'], manufacturer part number: ['11111'], sku: ['vi:11111'], part title: ['ultima 11111 reman', 'door mirror carquest 11111','mpa 11111 alternator / generator and related components - alternator', 'alternator quality-built 11111 reman fits 12-15 honda crosstour 2.4l-l4', 'alternator fvp 11111 reman fits 2012 honda crosstour 2.4l-l4', 'bishko automotive literature 11111 books and manuals - owners manual', 'pure energ...
# 71                                                                                                                                                                                                                                                                                                                             brand: ['beck/arnley'], fitment: ['direct replacement'], manufacturer part number: ['143-0081, 1430081'], category: 1.0, item_title: one new beckarnley engine coolant thermostat 1430081
# 72   brand: ['beck/arnley'], type: ['direct ignition coil'], oem part number: ['26020075'], manufacturer part number: ['178-8412'], sku: ['544:178-8412'], part title: ['carquest 178-8412', 'auto plus/beck/arnley 1788412 ignition coil - ignition coil', 'advance 178-8412 ignition coil', 'auto extra 178-8412', 'direct ignition coil beck/arnley 178-8412'], part brands: ['carquest', 'auto plus', 'autoextra/beck/arnley', 'beck/arnley', 'advance/ignition & engine filters'], subtype: ['ignition coil', 'd...
# 73                                             brand: ['beurbestparts'], make: saturn, model: vue, year: ['2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009'], fitment: ['direct replacement', 'no'], type: ['ignition coil', 'blade', 'coil on plug (cop)', 'plug in'], oem part number: ['uf400'], manufacturer part number: ['be133365u01', 'yes'], vehicle identification number: ['no'], category: 3.0, item_title: ignition coils spark plugs for 2004-2007 saturn vue 2001-2009 acura mdx 35l
# 74   brand: ['bmw', 'genuine oem'], make: bmw, model: 535i, year: ['8991', '1989', '1990', '1991'], manufacturer part number: ['1 726 685'], sku: ['188369'], category: 0.0, item_title: bmw 535i engine computer ecu dme e34 89-91 oem 1 726 685 735i, cleaned_desc: bmw 535i engine computer ecu dme e34 89-91 oem 1 726 685 735i breaking down 1990 bmw 535i this listing is for: engine computer oem part#: 1 726 685 fitment: 89-91 e34 please confirm with your dealer. shipments us shipping all large items t...
# 75   brand: ['bmw'], make: bmw, model: 750i, year: ['2009', '2010', '2011', '2012', '2013', '2014', '2015'], fitment: ['direct replacement'], type: ['terminal', 'female'], oem part number: ['9223473'], manufacturer part number: ['9223473'], category: 0.0, item_title: 09-15 bmw f04 7 750i 750li active hybrid positive battery terminal cable- oem, cleaned_desc: when you buy our item you agree to our terms and conditions item condition: good / normal use / as shown in the photos / it is buyer's respo...
# 76                                     brand: ['bmw'], make: bmw, model: bmw 325i, year: ['2006', '2006'], type: ['ignition coil'], manufacturer part number: ['12137548553'], sku: ['0001425618', 'ny12-eff116-4139113'], part title: ['sic autoparts 12137548553 electrical connectors - ignition coil connector'], part brands: ['sic autoparts'], subtype: ['ignition coil connector'], part types: ['electrical connectors'], category: 3.0, item_title: used ignition coil fits 2006 bmw 325i 30l thru 306 grade a
# 77                                                                                                                                                                                                                                                                                           brand: ['bmw'], make: bmw, model: m5, year: ['1999', '2000', '2001', '2002', '2003'], manufacturer part number: ['1406869'], category: 2.0, item_title: 99-03 bmw e39 m5 s62 engine oil inlet outlet pressure hose pair oem
# 78                                                                                                                                                                                                                                                              brand: ['bmw'], make: bmw, model: x3, year: ['2015', '2013', '2014', '2015', '2016', '2017'], vehicle identification number: ['5uxwx9c59f0d52294'], sku: ['019698', '1109924'], category: 4.0, item_title: 13 - 17 bmw x3 flywheel or flex plate e675874
# 79   brand: ['bnr'], make: chrysler, model: sebring, year: ['1996', '1997', '1998', '1999', '2000'], type: ['alternator'], manufacturer part number: ['13592'], part title: ['alternator-vin: h, gas, fi, natural, convertible quality rebuilders 13592 reman', 'radiator osc 13592', 'alternator bbb industries 13592 reman fits 96-00 chrysler sebring 2.5l-v6', 'aim 13592 reman', 'alternator-convertible auto plus 13592 reman fits 96-97 chrysler sebring 2.4l-l4', 'pure energy 13592 alternator / generator a...
# 80                                                                                                                                                                                                                                         brand: ['bosch'], make: audi, year: ['1991', '1991'], oem part number: ['96711qy'], product name: ['distributor cap'], manufacturer part number: ['96711qy'], sku: ['400:96711qy'], category: 3.0, item_title: for 1991 audi 80 distributor cap bosch 96711qy distributor cap
# 81                                                                                                                                                                         brand: ['bosch'], make: hyundai, model: 6, year: ['2007', '2008'], type: ['spark plug', 'gasoline'], oem part number: ['6 bosch 8100'], manufacturer part number: ['6 bosch 8100', 'yes'], vehicle identification number: ['yes'], category: 3.0, item_title: 6 pack spark plugs bosch double platinum for 2007-2008 hyundai entourage v6-38l
# 82   brand: ['bosch'], type: ['engine auxiliary water pump'], manufacturer part number: ['0392023004'], part title: ['auto plus 0392023004 reman engine water pump', 'engine auxiliary water pump-(new) bosch 0392023004', 'pb/bosch 0392023004 engine water pump', 'engine auxiliary water pump-eng code: 112.949 advance 0392023004', 'auto extra 0392023004'], part brands: ['advance auto parts', 'bosch', 'auto plus', 'auto extra', 'pep boys'], subtype: ['engine water pump', 'engine auxiliary water pump'],...
# 83        brand: ['bosch'], type: ['spark plug'], manufacturer part number: ['f8dc4'], part title: ['auto plus/bosch f8dc4 secondary ignition - spark plug','spark plug-nickel bosch f8dc4', 'carquest/bosch f8dc4 secondary ignition - spark plug', 'auto extra f8dc4', 'advance f8dc4 spark plug'], part brands: ['carquest', 'bosch', 'auto plus', 'auto extra', 'advance/ignition & engine filters'], subtype: ['spark plug'], part types: ['secondary ignition'], category: 3.0, item_title: bosch spark plug f8dc4
# 84                                                                                                                                                                                                                                    brand: ['brand new','realray'], model: corvette, type: ['corvette servo kit'], oem part number: ['a74905bk, 74905bk, k77895b'], manufacturer part number: ['a74905bk'], category: 4.0, item_title: hi-performance corvette servo kit th700r4 4l60e 4l65e 4l70e th700-r4 piston kit
# 85                                                                                                                                                                                brand: ['bremi'], make: bmw, model: 530i, year: ['2017', '2018', '2019', '2020', '2017', '2018', '2019', '2020'], oem part number: ['24946kw'], product name: ['engine oil'], manufacturer part number: ['24946kw'], sku: ['400:24946kw'], category: 2.0, item_title: for 2017-2020 bmw 530i xdrive engine oil bremi 24946kw 2018 2019
# 86                                                                                                                                                                                                                                      brand: ['buick'], make: buick, model: encore, year: ['2015', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020'], vehicle identification number: ['kl4cjfsb4fb204268'], sku: ['180390', '2129949'], category: 4.0, item_title: transfer case fits 13-20 trax 2129949
# 87                                                                                                                                                                                                                                            brand: ['buick'], make: buick, model: encore, year: ['2018'], type: ['auto'], manufacturer part number: ['encore347667339lkq'], vehicle identification number: ['kl4cjasb4jb682217'], category: 4.0, item_title: 2018 buick encore transmission oem 38k miles lkq347667339
# 88   brand: ['buick'], make: buick, model: lucerne, year: ['2008', '2005', '2006', '2007', '2008', '2009'], vehicle identification number: ['1g4hp57228u142997'], sku: ['ac1635', '2318729'], category: 0.0, item_title: starter motor fits 05-09 allure 2318729, cleaned_desc: hollander welcome to our ebay store! starter motor fits 05-09 allure 2318729 description starter: tested in the vehicle to be in working condition. unbolted with all attached wires. donor vehicle model : lucerne year : 2008 milea...
# 89                                                                                                                                                                                                                                                                              brand: ['buyautoparts'], make: audi, model: jetta, type: ['cooling fan assembly'], manufacturer part number: ['19-20617an'], category: 1.0, item_title: for vw jetta beetle golf audi tt quattro new right side cooling fan assembly tcp
# 90   brand: ['buyautoparts'], make: buick, model: c10, year: ['1980'], type: ['alternator'], manufacturer part number: ['31-10531an'], category: 0.0, item_title: for buick century chevrolet c10 gmc c1500 1980 alternator gap, cleaned_desc: great auto parts description features: as one of the world's largest automotive parts suppliers, our parts are trusted every day by mechanics and vehicle owners worldwide. this alternator is manufactured and tested to the strictest oe car and truck standards for...
# 91                                                                                                                                                                                                                                                                                                 brand: ['buyautoparts'], make: buick, year: ['2006', '2007', '2008'], type: ['radiator'], manufacturer part number: ['19-00564an'], category: 1.0, item_title: for buick lucerne 2006 2007 2008 w 38l v6 radiator tcp
# 92   brand: ['buyautoparts'], make: lincoln, model: continental, type: ['starter'], manufacturer part number: ['30-06746an'], category: 0.0, item_title: for lincoln continental mercury sable ford taurus starter csw, cleaned_desc: welcome to car steering menu about this item as one of the world's largest automotive parts suppliers, our parts are trusted every day by mechanics and vehicle owners worldwide. this starter is manufactured and tested to the strictest oe car and truck standards for unpar...
# ...
# 449                                                                                                                                                                                                                                     {chevrolet, buick}                             {chevrolet, buick}  1
# 450                                                                                                                                                                                                                                                 {ford}                                         {ford}  1
# 451                                                                                                                                                                                                                                               {saturn}                                       {saturn}  1
# 452                                                                                                                                                                                                                                         {kia, hyundai}         {chevrolet, pontiac, cadillac,, buick}  0
# 453                                                                                                                                                                                                                                        {lexus, toyota}                                {lexus, toyota}  1
# 454                                                                                                                                                                                                                                              {porsche}                                      {porsche}  1
# 455                                                                                                                                                                                                                                                 {audi}                                         {audi}  1
# 456                                                                                                                                                                                                                                           {volkswagen}                             {volkswagen, audi}  1
# 457                                                                                                                                                                                                                                     {volkswagen, audi}                             {volkswagen, audi}  1
# 458                                                                                                                                                                                                                                     {volkswagen, audi}                             {volkswagen, audi}  1
# 459                                                                                                                                                                                                                                                  {bmw}                                          {bmw}  1
# 460                                                                                                                                                                                                                                                  {bmw}                                          {bmw}  1
# 461                                                                                                                                                                                                                                                  {bmw}                                          {bmw}  1
# 462                                                                                                                                                                                                                                                  {bmw}                                          {bmw}  1
# 463                                                                                                                                                                                                                           {jeep, ram, dodge, chrysler}                   {jeep, ram, dodge, chrysler}  1
# 464                                                                                                                                                                                                                                        {mercury, ford}                       {mercury, lincoln, ford}  1
# 465                                                                                                                                                                                                                                                {honda}                                        {honda}  1
# 466                                                                                                                                                                                                                                         {honda, acura}                                        {honda}  1
# 467                                                                                                                                                                                                   {dodge, freightliner, chrysler, jeep, mercedes-benz}                                {mercedes-benz}  1
# 468                                                                                                                                                                                                                                     {nissan, infiniti}                             {nissan, infiniti}  1
# 469                                                                                                                                                                                                                                               {toyota}                                       {toyota}  1
# 470                                                                                                                                                                                                                                        {mercedes-benz}                                {mercedes-benz}  0
# 471                                                                                                                                                                                                                                        {mercedes-benz}                                {mercedes-benz}  0
# 472                                                                                                                                                                                                                                     {cadillac, saturn}                                     {cadillac}  1
# 473                                                                                                                                                                                                                                           {volkswagen}                                   {volkswagen}  1
# 474                                                                                                                                                                                                                          {mercury, vpg, lincoln, ford}                  {mercury, vpg, lincoln, ford}  1
# 475                                                                                                                                                                                                                                                {volvo}                                        {volvo}  1
# 476                                                                                                                                                                                                                                               {nissan}                                       {nissan}  0
# 477                                                                                                                                                                                                                                                {scion}             {chevrolet, pontiac, cadillac, gm}  1
# 478                                                                                                                                                                                                                                                {volvo}                                        {volvo}  1
# 479                                                                                                                                                                                                                                                {dodge}                                        {dodge}  1
# 480                                                                                                                                                                                                                                                 {ford}                                         {ford}  1
# 481                                                                                                                                                                                                                                            {chevrolet}                                    {chevrolet}  0
# 482                                                                                                                                                                                                                                                  {gmc}                                          {gmc}  1
# 483                                                                                                                                                                                                                      {geo, pontiac, suzuki, chevrolet}                                    {chevrolet}  0
# 484                                                                                                                                                                                                                                               {subaru}                                        {honda}  0
# 485                                                                                                                                                                                                                                               {subaru}                                       {subaru}  1
# 486                                                                                                                                                                                                                                            {chevrolet}                                    {chevrolet}  1
# 487                                                                                                                                                                                                                              {international harvester}                      {international harvester}  0
# 488                                                                                                                                                                                                                                                {dodge}                                        {dodge}  0
# 489                                                                                                                                                                                                                                                 {jeep}                                         {jeep}  1
# 490                                                                                                                                                                                                                                             {chrysler}                                       {westar}  0
# 491                                                                                                                                                                                                                                                {acura}                                        {acura}  1
# 492                                                                                                                                                                                                                                         {honda, acura}                                 {honda, acura}  1
# 493                                                                                                                                                                                                                                        {mercedes-benz}                                {mercedes-benz}  0
# 494                                                                                                                                                                                                                                           {mitsubishi}    {mitsubishi, dodge, je, chrysler, plymouth}  0
# 495                                                                                                                                                                                                                                               {toyota}                                       {toyota}  1
# 496                                                                                                                                                                                                                                                {dodge}                                        {dodge}  1
# 497                                                                                                                                                                                                                                                 {jeep}                                         {jeep}  0
# 498                                                                                                                                                                                                                                        {mercedes-benz}                                {mercedes-benz}  1
# 499                                                                                                                                                                                                                                                {volvo}                                        {volvo}  1

# %%
print("\nOverall metrics for has_desc = 1:")
print(overall_metrics_1)


print("\nOverall metrics for has_desc = 0:")
print(overall_metrics_0)
# Out:
# Overall metrics for has_desc = 1:
# {'Precision': 0.9414331736482472, 'Recall': 0.810126582278481, 'Accuracy': 0.8206521739130435}
#
# Overall metrics for has_desc = 0:
# {'Precision': 0.5172607619678126, 'Recall': 0.4155405405405405, 'Accuracy': 0.3939393939393939}
